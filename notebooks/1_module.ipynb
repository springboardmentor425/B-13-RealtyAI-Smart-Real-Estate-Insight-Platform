# %%
import pandas as pd

# %%
data = pd.read_csv("../dataset/dataset.csv")

# %%
pd.DataFrame({
    "price": data["price"].head(2).values,
    "area": data["area"].head(2).values
})
# Out:
#         price    area
# 0  28900000.0  2464.0
# 1  20000000.0  1920.0

# %%
pd.DataFrame({
    "num_bed_rooms": data["num_bed_rooms"].head(2).values,
    "num_bath_rooms": data["num_bath_rooms"].head(2).values
})
# Out:
#    num_bed_rooms  num_bath_rooms
# 0            3.0             4.0
# 1            3.0             3.0

# %%
pd.DataFrame({
    "price_per_sqft": data["price_per_sqft"].head(2).values,
    "city": data["city"].head(2).values
}, index=data["locality"].head(2).values)
# Out:
#                  price_per_sqft   city
# Dhanmondi          11728.896104  Dhaka
# Bashundhara R-A    10416.666667  Dhaka

# %%
pd.Series(data["price"].head(5).values)
# Out:
# 0    28900000.0
# 1    20000000.0
# 2    10800000.0
# 3    10500000.0
# 4     8000000.0
# dtype: float64

# %%
pd.Series(
    data["area"].head(3).values,
    index=data["city"].head(3).values,
    name="Area"
)
# Out:
# Dhaka    2464.0
# Dhaka    1920.0
# Dhaka    1445.0
# Name: Area, dtype: float64

# %%
data.shape
# Out:
# (18754, 22)

# %%
data.head()
# Out:
#      area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0  2464.0     Apartment     Residential             4.0            3.0
# 1  1920.0     Apartment     Residential             3.0            3.0
# 2  1445.0     Apartment     Residential             3.0            3.0
# 3  1475.0     Apartment     Residential             3.0            3.0
# 4  1066.0     Apartment     Residential             2.0            3.0
#
#         price                                       property_url purpose  \
# 0  28900000.0  https://www.bproperty.com/en/property/details-...    Sale
# 1  20000000.0  https://www.bproperty.com/en/property/details-...    Sale
# 2  10800000.0  https://www.bproperty.com/en/property/details-...    Sale
# 3  10500000.0  https://www.bproperty.com/en/property/details-...    Sale
# 4   8000000.0  https://www.bproperty.com/en/property/details-...    Sale
#
#     city         locality  ... relaxation_amenity_count  \
# ...
