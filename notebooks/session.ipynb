# %%
import pandas as pd
d = {
'sales': [100000,222000,1000000,522000,111111,222222,1111111,20000,75000,90000,1000000,10000],
'city': ['Tampa','Tampa','Orlando','Jacksonville','Miami','Jacksonville','Miami','Miami','Orlando','Orlando','Orlando','Orlando'],
'size': ['Small', 'Medium','Large','Large','Small','Medium','Large','Small','Medium','Medium','Medium','Small'],
'store_type': ['Retail','Outlet','Retail','Online','Retail','Outlet','Retail','Online','Outlet','Retail','Retail','Online']
}

# %%
df = pd.DataFrame(data=d)
df.head()
# Out:
#      sales          city    size store_type
# 0   100000         Tampa   Small     Retail
# 1   222000         Tampa  Medium     Outlet
# 2  1000000       Orlando   Large     Retail
# 3   522000  Jacksonville   Large     Online
# 4   111111         Miami   Small     Retail

# %%
from sklearn.preprocessing import OneHotEncoder
