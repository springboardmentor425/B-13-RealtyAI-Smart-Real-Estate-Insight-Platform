# %%
import pandas as pd
city_df = pd.read_csv('/home/sukesh/Desktop/RealtyAI/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/dataset/City_time_series.csv')

# %%
city_df
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# ...

# %%
city_df.RegionName
# Out:
# 0             abbottstownadamspa
# 1              aberdeenbinghamid
# 2              aberdeenharfordmd
# 3               aberdeenmonroems
# 4                aberdeenmoorenc
#                    ...
# 3762561      zirconiahendersonnc
# 3762562    zolfo_springshardeefl
# 3762563    zumbro_fallswabashamn
# 3762564        zumbrotagoodhuemn
# 3762565      zuniisle_of_wightva
# Name: RegionName, Length: 3762566, dtype: str

# %%
city_df['RegionName']
# Out:
# 0             abbottstownadamspa
# 1              aberdeenbinghamid
# 2              aberdeenharfordmd
# 3               aberdeenmonroems
# 4                aberdeenmoorenc
#                    ...
# 3762561      zirconiahendersonnc
# 3762562    zolfo_springshardeefl
# 3762563    zumbro_fallswabashamn
# 3762564        zumbrotagoodhuemn
# 3762565      zuniisle_of_wightva
# Name: RegionName, Length: 3762566, dtype: str

# %%
city_df['RegionName'][0]
# Out:
# 'abbottstownadamspa'

# %%
city_df.iloc[0]
# Out:
# Date                                            1996-04-30
# RegionName                              abbottstownadamspa
# InventorySeasonallyAdjusted_AllHomes                   NaN
# InventoryRaw_AllHomes                                  NaN
# MedianListingPricePerSqft_1Bedroom                     NaN
#                                                ...
# ZRI_AllHomes                                           NaN
# ZRI_AllHomesPlusMultifamily                            NaN
# ZriPerSqft_AllHomes                                    NaN
# Zri_MultiFamilyResidenceRental                         NaN
# Zri_SingleFamilyResidenceRental                        NaN
# Name: 0, Length: 81, dtype: object

# %%
city_df.iloc[:,[0,1,47,62,63,64,65,66,67,68,69,70,71,72]]
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          MedianRentalPrice_MultiFamilyResidence5PlusUnits  Sale_Counts  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...

# %%
city_df.iloc[:3,1]
# Out:
# 0    abbottstownadamspa
# 1     aberdeenbinghamid
# 2     aberdeenharfordmd
# Name: RegionName, dtype: str

# %%
city_df.iloc[-1:]
# Out:
#                Date           RegionName  \
# 3762565  2017-12-31  zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 3762565                                   NaN                    NaN
#
#          MedianListingPricePerSqft_1Bedroom  \
# 3762565                                 NaN
#
#          MedianListingPricePerSqft_2Bedroom  \
# 3762565                                 NaN
#
#          MedianListingPricePerSqft_3Bedroom  \
# 3762565                                 NaN
#
#          MedianListingPricePerSqft_4Bedroom  \
# 3762565                                 NaN
#
#          MedianListingPricePerSqft_5BedroomOrMore  \
# 3762565                                       NaN
#
#          MedianListingPricePerSqft_AllHomes  ...  ZHVI_BottomTier  \
# 3762565                                 NaN  ...         123700.0
#
#          ZHVI_CondoCoop  ZHVI_MiddleTier  ZHVI_SingleFamilyResidence  \
# ...

# %%
city_df.RegionName == 'zuniisle_of_wightva'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3762561    False
# 3762562    False
# 3762563    False
# 3762564    False
# 3762565     True
# Name: RegionName, Length: 3762566, dtype: bool

# %%
city_df.loc[city_df.RegionName == 'zuniisle_of_wightva']
# Out:
#                Date           RegionName  \
# 11427    1996-04-30  zuniisle_of_wightva
# 22998    1996-05-31  zuniisle_of_wightva
# 34629    1996-06-30  zuniisle_of_wightva
# 46265    1996-07-31  zuniisle_of_wightva
# 57914    1996-08-31  zuniisle_of_wightva
# ...             ...                  ...
# 3696655  2017-08-31  zuniisle_of_wightva
# 3713156  2017-09-30  zuniisle_of_wightva
# 3729642  2017-10-31  zuniisle_of_wightva
# 3746114  2017-11-30  zuniisle_of_wightva
# 3762565  2017-12-31  zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 11427                                     NaN                    NaN
# 22998                                     NaN                    NaN
# 34629                                     NaN                    NaN
# 46265                                     NaN                    NaN
# 57914                                     NaN                    NaN
# ...

# %%
city_df.loc[(city_df.RegionName == 'zuniisle_of_wightva') & (city_df.ZHVI_4bedroom > 300000)]
# Out:
#                Date           RegionName  \
# 1578692  2006-04-30  zuniisle_of_wightva
# 1592394  2006-05-31  zuniisle_of_wightva
# 1606096  2006-06-30  zuniisle_of_wightva
# 1619798  2006-07-31  zuniisle_of_wightva
# 1633513  2006-08-31  zuniisle_of_wightva
# 1647228  2006-09-30  zuniisle_of_wightva
# 1660943  2006-10-31  zuniisle_of_wightva
# 1674658  2006-11-30  zuniisle_of_wightva
# 1688373  2006-12-31  zuniisle_of_wightva
# 1702088  2007-01-31  zuniisle_of_wightva
# 1715819  2007-02-28  zuniisle_of_wightva
# 1729550  2007-03-31  zuniisle_of_wightva
# 1743281  2007-04-30  zuniisle_of_wightva
# 1757012  2007-05-31  zuniisle_of_wightva
# 1770743  2007-06-30  zuniisle_of_wightva
# 1784474  2007-07-31  zuniisle_of_wightva
# 1798233  2007-08-31  zuniisle_of_wightva
# 1811992  2007-09-30  zuniisle_of_wightva
# 1825751  2007-10-31  zuniisle_of_wightva
# 1839510  2007-11-30  zuniisle_of_wightva
# 1853269  2007-12-31  zuniisle_of_wightva
# 1867019  2008-01-31  zuniisle_of_wightva
# ...

# %%
city_df.loc[(city_df.RegionName == 'zuniisle_of_wightva') | (city_df.ZHVI_4bedroom > 300000)]
# Out:
#                Date                      RegionName  \
# 45       1996-04-30       agoura_hillslos_angelesca
# 60       1996-04-30             alamocontra_costaca
# 83       1996-04-30                  aldieloudounva
# 88       1996-04-30  alexandria_townshiphunterdonnj
# 114      1996-04-30               allendalebergennj
# ...             ...                             ...
# 3762535  2017-12-31               yuba_citysutterca
# 3762536  2017-12-31         yucaipasan_bernardinoca
# 3762541  2017-12-31       zacharyeast_baton_rougela
# 3762559  2017-12-31               zionsvilleboonein
# 3762565  2017-12-31             zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 45                                        NaN                    NaN
# 60                                        NaN                    NaN
# 83                                        NaN                    NaN
# ...

# %%
city_df.loc[(city_df.RegionName.isin(['zuniisle_of_wightva', 'allendalebergennj']) ) ]
# Out:
#                Date           RegionName  \
# 114      1996-04-30    allendalebergennj
# 11427    1996-04-30  zuniisle_of_wightva
# 11544    1996-05-31    allendalebergennj
# 22998    1996-05-31  zuniisle_of_wightva
# 23116    1996-06-30    allendalebergennj
# ...             ...                  ...
# 3729642  2017-10-31  zuniisle_of_wightva
# 3729815  2017-11-30    allendalebergennj
# 3746114  2017-11-30  zuniisle_of_wightva
# 3746287  2017-12-31    allendalebergennj
# 3762565  2017-12-31  zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 114                                       NaN                    NaN
# 11427                                     NaN                    NaN
# 11544                                     NaN                    NaN
# 22998                                     NaN                    NaN
# 23116                                     NaN                    NaN
# ...

# %%
city_df.loc[city_df.ZHVI_BottomTier.notnull()]
# Out:
#                Date             RegionName  \
# 2        1996-04-30      aberdeenharfordmd
# 7        1996-04-30      abingdonharfordmd
# 10       1996-04-30   abingtonmontgomerypa
# 11       1996-04-30     abingtonplymouthma
# 12       1996-04-30         abramsocontowi
# ...             ...                    ...
# 3762559  2017-12-31      zionsvilleboonein
# 3762561  2017-12-31    zirconiahendersonnc
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 2                                         NaN                    NaN
# 7                                         NaN                    NaN
# 10                                        NaN                    NaN
# 11                                        NaN                    NaN
# 12                                        NaN                    NaN
# ...

# %%
city_df['InventorySeasonallyAdjusted_AllHomes'] = '0'

# %%
city_df['InventorySeasonallyAdjusted_AllHomes']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 3762561    0
# 3762562    0
# 3762563    0
# 3762564    0
# 3762565    0
# Name: InventorySeasonallyAdjusted_AllHomes, Length: 3762566, dtype: str

# %%
city_df
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#         InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                          0                    NaN
# 1                                          0                    NaN
# 2                                          0                    NaN
# 3                                          0                    NaN
# 4                                          0                    NaN
# ...

# %%
city_df
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                           1                    NaN
# 1                                           2                    NaN
# 2                                           3                    NaN
# 3                                           4                    NaN
# 4                                           5                    NaN
# ...

# %%
city_df.shape
# Out:
# (3762566, 81)

# %%
city_df['InventorySeasonallyAdjusted_AllHomes'] = range(1,len(city_df)+1)
