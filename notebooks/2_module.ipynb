# %%
import pandas as pd
data = pd.read_csv("../dataset/dataset.csv")

# %%
data
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...

# %%
data.city
# Out:
# 0        Dhaka
# 1        Dhaka
# 2        Dhaka
# 3        Dhaka
# 4        Dhaka
#          ...
# 18749    Dhaka
# 18750    Dhaka
# 18751    Dhaka
# 18752    Dhaka
# 18753    Dhaka
# Name: city, Length: 18754, dtype: str

# %%
data["city"]
# Out:
# 0        Dhaka
# 1        Dhaka
# 2        Dhaka
# 3        Dhaka
# 4        Dhaka
#          ...
# 18749    Dhaka
# 18750    Dhaka
# 18751    Dhaka
# 18752    Dhaka
# 18753    Dhaka
# Name: city, Length: 18754, dtype: str

# %%
data["city"][0]
# Out:
# 'Dhaka'

# %%
data.iloc[0]
# Out:
# area                                                                                2464.0
# building_type                                                                    Apartment
# building_nature                                                                Residential
# num_bath_rooms                                                                         4.0
# num_bed_rooms                                                                          3.0
# price                                                                           28900000.0
# property_url                             https://www.bproperty.com/en/property/details-...
# purpose                                                                               Sale
# city                                                                                 Dhaka
# locality                                                                         Dhanmondi
# ...

# %%
data.iloc[:, 0]
# Out:
# 0        2464.0
# 1        1920.0
# 2        1445.0
# 3        1475.0
# 4        1066.0
#           ...
# 18749     375.0
# 18750     375.0
# 18751     800.0
# 18752     800.0
# 18753    1600.0
# Name: area, Length: 18754, dtype: float64

# %%
data.iloc[:3, 0]
# Out:
# 0    2464.0
# 1    1920.0
# 2    1445.0
# Name: area, dtype: float64

# %%
data.iloc[[0, 1, 2], 0]
# Out:
# 0    2464.0
# 1    1920.0
# 2    1445.0
# Name: area, dtype: float64

# %%
data.iloc[-5:]
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
#            price                                       property_url purpose  \
# 18749  3600000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18750  3600000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18751  4800000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18752  4800000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18753  2850000.0  https://www.thetolet.com/en/dhaka/adabor/31021...    Rent
#
# ...

# %%
data.loc[0, "city"]
# Out:
# 'Dhaka'

# %%
data.loc[:, ["building_type", "purpose", "city"]]
# Out:
#       building_type purpose   city
# 0         Apartment    Sale  Dhaka
# 1         Apartment    Sale  Dhaka
# 2         Apartment    Sale  Dhaka
# 3         Apartment    Sale  Dhaka
# 4         Apartment    Sale  Dhaka
# ...             ...     ...    ...
# 18749     Apartment    Rent  Dhaka
# 18750     Apartment    Rent  Dhaka
# 18751     Apartment    Rent  Dhaka
# 18752     Apartment    Rent  Dhaka
# 18753        Office    Rent  Dhaka
#
# [18754 rows x 3 columns]

# %%
data.set_index("locality")
# Out:
#                    area building_type building_nature  num_bath_rooms  \
# locality
# Dhanmondi        2464.0     Apartment     Residential             4.0
# Bashundhara R-A  1920.0     Apartment     Residential             3.0
# Banasree         1445.0     Apartment     Residential             3.0
# Uttara           1475.0     Apartment     Residential             3.0
# Sutrapur         1066.0     Apartment     Residential             2.0
# ...                 ...           ...             ...             ...
# Bashundhara R.A   375.0     Apartment     Residential             1.0
# Bashundhara R.A   375.0     Apartment     Residential             1.0
# Bashundhara R.A   800.0     Apartment     Residential             2.0
# Bashundhara R.A   800.0     Apartment     Residential             2.0
# Adabor           1600.0        Office      Commercial             3.0
#
#                  num_bed_rooms       price  \
# locality
# Dhanmondi                  3.0  28900000.0
# ...

# %%
data.city == "Dhaka"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18749    True
# 18750    True
# 18751    True
# 18752    True
# 18753    True
# Name: city, Length: 18754, dtype: bool

# %%
data.loc[data.city == "Dhaka"]
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...

# %%
data.loc[(data.city == "Dhaka") & (data.price >= 1000000)]
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...

# %%
data.loc[(data.city == "Dhaka") | (data.price >= 1000000)]
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...

# %%
data.loc[data.city.isin(["Dhaka", "Chattogram"])]
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...
