# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("../dataset/dataset.csv")

# %%
df.head()
# Out:
#      area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0  2464.0     Apartment     Residential             4.0            3.0
# 1  1920.0     Apartment     Residential             3.0            3.0
# 2  1445.0     Apartment     Residential             3.0            3.0
# 3  1475.0     Apartment     Residential             3.0            3.0
# 4  1066.0     Apartment     Residential             2.0            3.0
#
#         price                                       property_url purpose  \
# 0  28900000.0  https://www.bproperty.com/en/property/details-...    Sale
# 1  20000000.0  https://www.bproperty.com/en/property/details-...    Sale
# 2  10800000.0  https://www.bproperty.com/en/property/details-...    Sale
# 3  10500000.0  https://www.bproperty.com/en/property/details-...    Sale
# 4   8000000.0  https://www.bproperty.com/en/property/details-...    Sale
#
#     city         locality  ... relaxation_amenity_count  \
# 0  Dhaka        Dhanmondi  ...                        1
# 1  Dhaka  Bashundhara R-A  ...                        1
# 2  Dhaka         Banasree  ...                        1
# 3  Dhaka           Uttara  ...                        1
# 4  Dhaka         Sutrapur  ...                        1
#
#   security_amenity_count  maintenance_or_cleaning_amenity_count  \
# 0                      2                                      1
# 1                      1                                      2
# 2                      2                                      2
# 3                      2                                      3
# 4                      1                                      2
#
#    social_amenity_count  expendable_amenity_count  \
# 0                     1                         3
# 1                     1                         3
# 2                     1                         1
# 3                     1                         3
# 4                     1                         4
#
#    service_staff_amenity_count  unclassify_amenity_count  division  \
# 0                            3                         4     Dhaka
# 1                            2                         3     Dhaka
# 2                            3                         4     Dhaka
# 3                            3                         4     Dhaka
# 4                            3                         4     Dhaka
#
#               zone price_per_sqft
# 0        Dhanmondi   11728.896104
# 1  Bashundhara R/A   10416.666667
# 2         Khilgaon    7474.048443
# 3           Uttara    7118.644068
# 4         Sutrapur    7504.690432
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
#            price                                       property_url purpose  \
# 18749  3600000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18750  3600000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18751  4800000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18752  4800000.0  https://www.thetolet.com/en/dhaka/bashundhara-...    Rent
# 18753  2850000.0  https://www.thetolet.com/en/dhaka/adabor/31021...    Rent
#
#         city         locality  ... relaxation_amenity_count  \
# 18749  Dhaka  Bashundhara R.A  ...                        1
# 18750  Dhaka  Bashundhara R.A  ...                        1
# 18751  Dhaka  Bashundhara R.A  ...                        1
# 18752  Dhaka  Bashundhara R.A  ...                        1
# 18753  Dhaka           Adabor  ...                        1
#
#       security_amenity_count  maintenance_or_cleaning_amenity_count  \
# 18749                      1                                      2
# 18750                      2                                      1
# 18751                      1                                      2
# 18752                      1                                      1
# 18753                      2                                      2
#
#        social_amenity_count  expendable_amenity_count  \
# 18749                     3                         4
# 18750                     1                         4
# 18751                     1                         3
# 18752                     1                         1
# 18753                     1                         1
#
#        service_staff_amenity_count  unclassify_amenity_count  division  \
# 18749                            2                        13     Dhaka
# 18750                            2                         1     Dhaka
# 18751                            3                         1     Dhaka
# 18752                            2                         1     Dhaka
# 18753                            2                         1     Dhaka
#
#                   zone price_per_sqft
# 18749  Bashundhara R/A        9600.00
# 18750  Bashundhara R/A        9600.00
# 18751  Bashundhara R/A        6000.00
# 18752  Bashundhara R/A        6000.00
# 18753      Mohammadpur        1781.25
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18754 entries, 0 to 18753
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   area                                   18754 non-null  float64
#  1   building_type                          18754 non-null  str
#  2   building_nature                        18754 non-null  str
#  3   num_bath_rooms                         18754 non-null  float64
#  4   num_bed_rooms                          18754 non-null  float64
#  5   price                                  18754 non-null  float64
#  6   property_url                           18754 non-null  str
#  7   purpose                                18754 non-null  str
#  8   city                                   18754 non-null  str
#  9   locality                               18754 non-null  str
#  10  address                                18754 non-null  str
#  11  id                                     18754 non-null  str
#  12  relaxation_amenity_count               18754 non-null  int64
#  13  security_amenity_count                 18754 non-null  int64
#  14  maintenance_or_cleaning_amenity_count  18754 non-null  int64
#  15  social_amenity_count                   18754 non-null  int64
#  16  expendable_amenity_count               18754 non-null  int64
#  17  service_staff_amenity_count            18754 non-null  int64
#  18  unclassify_amenity_count               18754 non-null  int64
#  19  division                               18754 non-null  str
#  20  zone                                   18754 non-null  str
#  21  price_per_sqft                         18754 non-null  float64
# dtypes: float64(5), int64(7), str(10)
# memory usage: 3.1 MB

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])
print("Numeric Columns:")
print(numeric_df.columns)
# Out:
# Numeric Columns:
# Index(['area', 'num_bath_rooms', 'num_bed_rooms', 'price',
#        'relaxation_amenity_count', 'security_amenity_count',
#        'maintenance_or_cleaning_amenity_count', 'social_amenity_count',
#        'expendable_amenity_count', 'service_staff_amenity_count',
#        'unclassify_amenity_count', 'price_per_sqft'],
#       dtype='str')

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(numeric_df)
scaled_df = pd.DataFrame(scaled_data, columns=numeric_df.columns)

# %%
scaled_df.head()
# Out:
#        area  num_bath_rooms  num_bed_rooms     price  \
# 0  0.000205        0.061224       0.036364  0.013920
# 1  0.000160        0.040816       0.036364  0.009633
# 2  0.000120        0.040816       0.036364  0.005202
# 3  0.000123        0.040816       0.036364  0.005057
# 4  0.000089        0.020408       0.036364  0.003853
#
#    relaxation_amenity_count  security_amenity_count  \
# 0                       0.0                    0.25
# 1                       0.0                    0.00
# 2                       0.0                    0.25
# 3                       0.0                    0.25
# 4                       0.0                    0.00
#
#    maintenance_or_cleaning_amenity_count  social_amenity_count  \
# 0                                    0.0                   0.0
# 1                                    0.5                   0.0
# 2                                    0.5                   0.0
# 3                                    1.0                   0.0
# 4                                    0.5                   0.0
#
#    expendable_amenity_count  service_staff_amenity_count  \
# 0                       0.4                     0.666667
# 1                       0.4                     0.333333
# 2                       0.0                     0.666667
# 3                       0.4                     0.666667
# 4                       0.6                     0.666667
#
#    unclassify_amenity_count  price_per_sqft
# 0                  0.176471        0.970168
# 1                  0.117647        0.861626
# 2                  0.176471        0.618224
# 3                  0.176471        0.588826
# 4                  0.176471        0.620758

# %%
scaled_df
# Out:
#            area  num_bath_rooms  num_bed_rooms     price  \
# 0      0.000205        0.061224       0.036364  0.013920
# 1      0.000160        0.040816       0.036364  0.009633
# 2      0.000120        0.040816       0.036364  0.005202
# 3      0.000123        0.040816       0.036364  0.005057
# 4      0.000089        0.020408       0.036364  0.003853
# ...         ...             ...            ...       ...
# 18749  0.000031        0.000000       0.000000  0.001734
# 18750  0.000031        0.000000       0.000000  0.001734
# 18751  0.000067        0.020408       0.018182  0.002312
# 18752  0.000067        0.020408       0.018182  0.002312
# 18753  0.000133        0.040816       0.036364  0.001373
#
#        relaxation_amenity_count  security_amenity_count  \
# 0                           0.0                    0.25
# 1                           0.0                    0.00
# 2                           0.0                    0.25
# 3                           0.0                    0.25
# 4                           0.0                    0.00
# ...                         ...                     ...
# 18749                       0.0                    0.00
# 18750                       0.0                    0.25
# 18751                       0.0                    0.00
# 18752                       0.0                    0.00
# 18753                       0.0                    0.25
#
#        maintenance_or_cleaning_amenity_count  social_amenity_count  \
# 0                                        0.0                   0.0
# 1                                        0.5                   0.0
# 2                                        0.5                   0.0
# 3                                        1.0                   0.0
# 4                                        0.5                   0.0
# ...                                      ...                   ...
# 18749                                    0.5                   0.5
# 18750                                    0.0                   0.0
# 18751                                    0.5                   0.0
# 18752                                    0.0                   0.0
# 18753                                    0.5                   0.0
#
#        expendable_amenity_count  service_staff_amenity_count  \
# 0                           0.4                     0.666667
# 1                           0.4                     0.333333
# 2                           0.0                     0.666667
# 3                           0.4                     0.666667
# 4                           0.6                     0.666667
# ...                         ...                          ...
# 18749                       0.6                     0.333333
# 18750                       0.6                     0.333333
# 18751                       0.4                     0.666667
# 18752                       0.0                     0.333333
# 18753                       0.0                     0.333333
#
#        unclassify_amenity_count  price_per_sqft
# 0                      0.176471        0.970168
# 1                      0.117647        0.861626
# 2                      0.176471        0.618224
# 3                      0.176471        0.588826
# 4                      0.176471        0.620758
# ...                         ...             ...
# 18749                  0.705882        0.794074
# 18750                  0.000000        0.794074
# 18751                  0.000000        0.496296
# 18752                  0.000000        0.496296
# 18753                  0.000000        0.147338
#
# [18754 rows x 12 columns]

# %%
manual_scaled = (numeric_df - numeric_df.min()) / (numeric_df.max() - numeric_df.min())

# %%
manual_scaled.head()
# Out:
#        area  num_bath_rooms  num_bed_rooms     price  \
# 0  0.000205        0.061224       0.036364  0.013920
# 1  0.000160        0.040816       0.036364  0.009633
# 2  0.000120        0.040816       0.036364  0.005202
# 3  0.000123        0.040816       0.036364  0.005057
# 4  0.000089        0.020408       0.036364  0.003853
#
#    relaxation_amenity_count  security_amenity_count  \
# 0                       0.0                    0.25
# 1                       0.0                    0.00
# 2                       0.0                    0.25
# 3                       0.0                    0.25
# 4                       0.0                    0.00
#
#    maintenance_or_cleaning_amenity_count  social_amenity_count  \
# 0                                    0.0                   0.0
# 1                                    0.5                   0.0
# 2                                    0.5                   0.0
# 3                                    1.0                   0.0
# 4                                    0.5                   0.0
#
#    expendable_amenity_count  service_staff_amenity_count  \
# 0                       0.4                     0.666667
# 1                       0.4                     0.333333
# 2                       0.0                     0.666667
# 3                       0.4                     0.666667
# 4                       0.6                     0.666667
#
#    unclassify_amenity_count  price_per_sqft
# 0                  0.176471        0.970168
# 1                  0.117647        0.861626
# 2                  0.176471        0.618224
# 3                  0.176471        0.588826
# 4                  0.176471        0.620758
