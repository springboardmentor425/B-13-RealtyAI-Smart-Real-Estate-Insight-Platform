# %%
import pandas as pd
reviews = pd.read_csv("C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv", index_col=0)
pd.set_option('display.max_rows', 5)

# %%
reviews
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# ...                        ...       ...        ...          ...       ...
# 2014-07-10 00:00:00   203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00   220600.0       3.0        2.5         1490      8102
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews.price
# Out:
# date
# 2014-05-02 00:00:00     313000.0
# 2014-05-02 00:00:00    2384000.0
#                          ...
# 2014-07-10 00:00:00     203400.0
# 2014-07-10 00:00:00     220600.0
# Name: price, Length: 4600, dtype: float64

# %%
reviews['price']
# Out:
# date
# 2014-05-02 00:00:00     313000.0
# 2014-05-02 00:00:00    2384000.0
#                          ...
# 2014-07-10 00:00:00     203400.0
# 2014-07-10 00:00:00     220600.0
# Name: price, Length: 4600, dtype: float64

# %%
reviews.iloc[0]
# Out:
# price       313000.0
# bedrooms         3.0
#               ...
# statezip    WA 98133
# country          USA
# Name: 2014-05-02 00:00:00, Length: 17, dtype: object

# %%
reviews.iloc[:, 0]
# Out:
# date
# 2014-05-02 00:00:00     313000.0
# 2014-05-02 00:00:00    2384000.0
#                          ...
# 2014-07-10 00:00:00     203400.0
# 2014-07-10 00:00:00     220600.0
# Name: price, Length: 4600, dtype: float64

# %%
reviews.iloc[:3, 0]
# Out:
# date
# 2014-05-02 00:00:00     313000.0
# 2014-05-02 00:00:00    2384000.0
# 2014-05-02 00:00:00     342000.0
# Name: price, dtype: float64

# %%
reviews.iloc[1:3, 0]
# Out:
# date
# 2014-05-02 00:00:00    2384000.0
# 2014-05-02 00:00:00     342000.0
# Name: price, dtype: float64

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# date
# 2014-05-02 00:00:00     313000.0
# 2014-05-02 00:00:00    2384000.0
# 2014-05-02 00:00:00     342000.0
# Name: price, dtype: float64

# %%
reviews.iloc[-5:]
# Out:
#                              price  bedrooms  bathrooms  sqft_living  \
# date
# 2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#                      sqft_lot  floors  waterfront  view  condition  \
# date
# 2014-07-09 00:00:00      6360     1.0           0     0          4
# 2014-07-09 00:00:00      7573     2.0           0     0          3
# 2014-07-09 00:00:00      7014     2.0           0     0          3
# 2014-07-10 00:00:00      6630     1.0           0     0          3
# 2014-07-10 00:00:00      8102     2.0           0     0          4
#
#                      sqft_above  sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews.loc[:, ['price', 'bedrooms', 'floors']]
# Out:
#                          price  bedrooms  floors
# date
# 2014-05-02 00:00:00   313000.0       3.0     1.5
# 2014-05-02 00:00:00  2384000.0       5.0     2.0
# ...                        ...       ...     ...
# 2014-07-10 00:00:00   203400.0       4.0     1.0
# 2014-07-10 00:00:00   220600.0       3.0     2.0
#
# [4600 rows x 3 columns]

# %%
reviews.set_index("street")
# Out:
#                           price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# street
# 18810 Densmore Ave N   313000.0       3.0        1.5         1340      7912
# 709 W Blaine St       2384000.0       5.0        2.5         3650      9050
# ...                         ...       ...        ...          ...       ...
# 5148 S Creston St      203400.0       4.0        2.0         2090      6630
# 18717 SE 258th St      220600.0       3.0        2.5         1490      8102
#
#                       floors  waterfront  view  condition  sqft_above  \
# street
# 18810 Densmore Ave N     1.5           0     0          3        1340
# 709 W Blaine St          2.0           0     4          5        3370
# ...                      ...         ...   ...        ...         ...
# 5148 S Creston St        1.0           0     0          3        1070
# 18717 SE 258th St        2.0           0     0          4        1490
#
# ...

# %%
reviews.price >= 1000000
# Out:
# date
# 2014-05-02 00:00:00    False
# 2014-05-02 00:00:00     True
#                        ...
# 2014-07-10 00:00:00    False
# 2014-07-10 00:00:00    False
# Name: price, Length: 4600, dtype: bool

# %%
reviews.loc[reviews.price <= 1000000]
# Out:
#                         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00  313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  342000.0       3.0        2.0         1930     11947
# ...                       ...       ...        ...          ...       ...
# 2014-07-10 00:00:00  203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00  220600.0       3.0        2.5         1490      8102
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     1.0           0     0          4        1930
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews.loc[(reviews.price == 1000000) & (reviews.bedrooms >= 3)]
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-15 00:00:00  1000000.0       5.0       4.25         3920     16258
# 2014-05-22 00:00:00  1000000.0       4.0       3.00         4260     18687
# 2014-06-02 00:00:00  1000000.0       3.0       2.50         2730      5832
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-15 00:00:00     2.0           0     0          3        2900
# 2014-05-22 00:00:00     2.0           0     0          3        4260
# 2014-06-02 00:00:00     2.0           0     0          3        2730
#
#                      sqft_basement  yr_built  yr_renovated             street  \
# date
# 2014-05-15 00:00:00           1020      1990          2009  2548 111th Ave SE
# 2014-05-22 00:00:00              0      1996             0   2432 267th Ct SE
# 2014-06-02 00:00:00              0      1998          2006   13428 NE 12th Pl
#
#                           city  statezip country
# ...

# %%
reviews.loc[(reviews.price == 1000000) | (reviews.bathrooms >= 3)]
# Out:
#                         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00  367500.0       4.0       3.00         3110      7231
# 2014-05-02 00:00:00  287200.0       3.0       3.00         1850     19966
# ...                       ...       ...        ...          ...       ...
# 2014-07-02 00:00:00       0.0       5.0       6.25         8020     21738
# 2014-07-02 00:00:00  245000.0       3.0       3.00         2470      7410
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     2.0           0     0          3        3110
# 2014-05-02 00:00:00     1.0           0     0          4        1090
# ...                     ...         ...   ...        ...         ...
# 2014-07-02 00:00:00     2.0           0     0          3        8020
# 2014-07-02 00:00:00     2.0           0     0          5        1860
#
#                      sqft_basement  yr_built  yr_renovated             street  \
# date
# ...

# %%
reviews.loc[reviews.street.isin(['Auburn', 'Maple Valley'])]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# ...                        ...       ...        ...          ...       ...
# 2014-07-10 00:00:00   203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00   220600.0       3.0        2.5         1490      8102
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews['street'] = 'random'
reviews['street']
# Out:
# date
# 2014-05-02 00:00:00    random
# 2014-05-02 00:00:00    random
#                         ...
# 2014-07-10 00:00:00    random
# 2014-07-10 00:00:00    random
# Name: street, Length: 4600, dtype: str

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# date
# 2014-05-02 00:00:00    4600
# 2014-05-02 00:00:00    4599
#                        ...
# 2014-07-10 00:00:00       2
# 2014-07-10 00:00:00       1
# Name: index_backwards, Length: 4600, dtype: int64
