# %%
import pandas as pd
city_df = pd.read_csv('/home/sukesh/Desktop/RealtyAI/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/dataset/City_time_series.csv')

# %%
city_df.rename(columns={'Date': 'Y-M-D'})
# Out:
#               Y-M-D             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# ...

# %%
city_df.rename(index={0: 'first_row', 1: 'second_row'})
# Out:
#                   Date             RegionName  \
# first_row   1996-04-30     abbottstownadamspa
# second_row  1996-04-30      aberdeenbinghamid
# 2           1996-04-30      aberdeenharfordmd
# 3           1996-04-30       aberdeenmonroems
# 4           1996-04-30        aberdeenmoorenc
# ...                ...                    ...
# 3762561     2017-12-31    zirconiahendersonnc
# 3762562     2017-12-31  zolfo_springshardeefl
# 3762563     2017-12-31  zumbro_fallswabashamn
# 3762564     2017-12-31      zumbrotagoodhuemn
# 3762565     2017-12-31    zuniisle_of_wightva
#
#             InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# first_row                                    NaN                    NaN
# second_row                                   NaN                    NaN
# 2                                            NaN                    NaN
# 3                                            NaN                    NaN
# ...

# %%
city_df.rename_axis("rows", axis='rows').rename_axis("columns", axis='columns')
# Out:
# columns        Date             RegionName  \
# rows
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
# columns  InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# rows
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# ...
