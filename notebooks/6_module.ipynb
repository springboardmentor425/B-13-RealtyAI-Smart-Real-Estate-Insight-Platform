# %%
import pandas as pd
data = pd.read_csv("../dataset/dataset.csv")

# %%
data.rename(columns={"price": "property_price"})
# Out:
#          area building_type building_nature  num_bath_rooms  num_bed_rooms  \
# 0      2464.0     Apartment     Residential             4.0            3.0
# 1      1920.0     Apartment     Residential             3.0            3.0
# 2      1445.0     Apartment     Residential             3.0            3.0
# 3      1475.0     Apartment     Residential             3.0            3.0
# 4      1066.0     Apartment     Residential             2.0            3.0
# ...       ...           ...             ...             ...            ...
# 18749   375.0     Apartment     Residential             1.0            1.0
# 18750   375.0     Apartment     Residential             1.0            1.0
# 18751   800.0     Apartment     Residential             2.0            2.0
# 18752   800.0     Apartment     Residential             2.0            2.0
# 18753  1600.0        Office      Commercial             3.0            3.0
#
# ...

# %%
data.rename(index={0: "firstEntry", 1: "secondEntry"})
# Out:
#                area building_type building_nature  num_bath_rooms  \
# firstEntry   2464.0     Apartment     Residential             4.0
# secondEntry  1920.0     Apartment     Residential             3.0
# 2            1445.0     Apartment     Residential             3.0
# 3            1475.0     Apartment     Residential             3.0
# 4            1066.0     Apartment     Residential             2.0
# ...             ...           ...             ...             ...
# 18749         375.0     Apartment     Residential             1.0
# 18750         375.0     Apartment     Residential             1.0
# 18751         800.0     Apartment     Residential             2.0
# 18752         800.0     Apartment     Residential             2.0
# 18753        1600.0        Office      Commercial             3.0
#
#              num_bed_rooms       price  \
# firstEntry             3.0  28900000.0
# secondEntry            3.0  20000000.0
# 2                      3.0  10800000.0
# ...

# %%
data.rename_axis("properties", axis="rows").rename_axis("features", axis="columns")
# Out:
# features      area building_type building_nature  num_bath_rooms  \
# properties
# 0           2464.0     Apartment     Residential             4.0
# 1           1920.0     Apartment     Residential             3.0
# 2           1445.0     Apartment     Residential             3.0
# 3           1475.0     Apartment     Residential             3.0
# 4           1066.0     Apartment     Residential             2.0
# ...            ...           ...             ...             ...
# 18749        375.0     Apartment     Residential             1.0
# 18750        375.0     Apartment     Residential             1.0
# 18751        800.0     Apartment     Residential             2.0
# 18752        800.0     Apartment     Residential             2.0
# 18753       1600.0        Office      Commercial             3.0
#
# features    num_bed_rooms       price  \
# properties
# 0                     3.0  28900000.0
# 1                     3.0  20000000.0
# 2                     3.0  10800000.0
# ...
