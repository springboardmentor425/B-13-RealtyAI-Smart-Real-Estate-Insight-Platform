# %%
import pandas as pd
reviews = pd.read_csv("C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv", index_col=0)
pd.set_option("display.max_rows", 5)

# %%
reviews.groupby('price').price.count()
# Out:
# price
# 0.0           49
# 7800.0         1
#               ..
# 12899000.0     1
# 26590000.0     1
# Name: price, Length: 1741, dtype: int64

# %%
reviews.groupby('price').price.min()
# Out:
# price
# 0.0                  0.0
# 7800.0            7800.0
#                  ...
# 12899000.0    12899000.0
# 26590000.0    26590000.0
# Name: price, Length: 1741, dtype: float64

# %%
reviews.groupby('bedrooms').apply(lambda df: df.city.iloc[0])
# Out:
# bedrooms
# 0.0    Seattle
# 1.0     Burien
#         ...
# 8.0    Seattle
# 9.0    Seattle
# Length: 10, dtype: str

# %%
reviews.groupby(['country', 'bedrooms']).apply(lambda df: df.loc[df.price.idxmax()])
# Out:
#                            2014-06-24 00:00:00  price  bathrooms  sqft_living  \
# country bedrooms
# USA     0.0      price               1295648.0    NaN        NaN          NaN
#                  bathrooms                 0.0    NaN        NaN          NaN
# ...                                        ...    ...        ...          ...
#         9.0      city                      NaN    NaN        NaN          NaN
#                  statezip                  NaN    NaN        NaN          NaN
#
#                             sqft_lot  floors  waterfront  view  condition  \
# country bedrooms
# USA     0.0      price           NaN     NaN         NaN   NaN        NaN
#                  bathrooms       NaN     NaN         NaN   NaN        NaN
# ...                              ...     ...         ...   ...        ...
#         9.0      city            NaN     NaN         NaN   NaN        NaN
#                  statezip        NaN     NaN         NaN   NaN        NaN
#
# ...

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#           len  min         max
# country
# USA      4600  0.0  26590000.0

# %%
countries_reviewed = reviews.groupby(['country', 'city']).street.agg([len])
countries_reviewed
# Out:
#                       len
# country city
# USA     Algona          5
#         Auburn        176
# ...                   ...
#         Woodinville   115
#         Yarrow Point    4
#
# [44 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#    country          city  len
# 0      USA        Algona    5
# 1      USA        Auburn  176
# ..     ...           ...  ...
# 42     USA   Woodinville  115
# 43     USA  Yarrow Point    4
#
# [44 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#    country                 city   len
# 2      USA   Beaux Arts Village     1
# 15     USA  Inglewood-Finn Hill     1
# ..     ...                  ...   ...
# 32     USA               Renton   293
# 35     USA              Seattle  1573
#
# [44 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#    country                 city   len
# 35     USA              Seattle  1573
# 32     USA               Renton   293
# ..     ...                  ...   ...
# 15     USA  Inglewood-Finn Hill     1
# 39     USA      Snoqualmie Pass     1
#
# [44 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#    country          city  len
# 0      USA        Algona    5
# 1      USA        Auburn  176
# ..     ...           ...  ...
# 42     USA   Woodinville  115
# 43     USA  Yarrow Point    4
#
# [44 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#    country                 city   len
# 2      USA   Beaux Arts Village     1
# 15     USA  Inglewood-Finn Hill     1
# ..     ...                  ...   ...
# 32     USA               Renton   293
# 35     USA              Seattle  1573
#
# [44 rows x 3 columns]
