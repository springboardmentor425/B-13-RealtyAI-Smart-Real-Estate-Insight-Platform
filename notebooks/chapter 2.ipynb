# %%
import pandas as pd
df=pd.read_csv("chapter1.csv")

# %%
df.iloc[0]
# Out:
# Title        M City Serviced Residence Jalan Ampang 886sf, ...
# Price                                                   690000
# Area                                                    AMPANG
# Category                                            Apartments
# Size                                                886 sq.ft.
# Bedrooms                                            2 Bedrooms
# Bathrooms                                          2 Bathrooms
# Name: 0, dtype: object

# %%
df.iloc[:10]
# Out:
#                                                Title   Price    Area  \
# 0  M City Serviced Residence Jalan Ampang 886sf, ...  690000  AMPANG
# 1  Cheapest fully furnished suria jelatek residen...  420000  AMPANG
# 2  3bed 2bath Suria Jelatek Condo 5 min to LRT an...  420000  AMPANG
# 3  [30% Below,1037sf] Direct Subsale not Auction!...  568444  AMPANG
# 4  HOT area | Tiara Ampang | Near Ampang Point | ...  618000  AMPANG
# 5  HOT area | City Garden Orchid Court | Taman Ni...  428000  AMPANG
# 6  100%LOAN SemiFurnish 705sf The Elements Condo ...  450000  AMPANG
# 7  Tiara Duta Condo G Floor 3R2B Taman Dangan Jay...  368000  AMPANG
# 8  Cheapest Suria Jelatek Residence Ampang Hilir ...  525000  AMPANG
# 9  1865sf LAKE VIEW Impiana On The Waterfront Con...  680000  AMPANG
#
#      Category         Size    Bedrooms    Bathrooms
# 0  Apartments   886 sq.ft.  2 Bedrooms  2 Bathrooms
# 1  Apartments   858 sq.ft.  3 Bedrooms  2 Bathrooms
# ...

# %%
df.iloc[[0,2,5]]
# Out:
#                                                Title   Price    Area  \
# 0  M City Serviced Residence Jalan Ampang 886sf, ...  690000  AMPANG
# 2  3bed 2bath Suria Jelatek Condo 5 min to LRT an...  420000  AMPANG
# 5  HOT area | City Garden Orchid Court | Taman Ni...  428000  AMPANG
#
#      Category         Size    Bedrooms    Bathrooms
# 0  Apartments   886 sq.ft.  2 Bedrooms  2 Bathrooms
# 2  Apartments   860 sq.ft.  3 Bedrooms  2 Bathrooms
# 5  Apartments  1250 sq.ft.  4 Bedrooms  2 Bathrooms

# %%
df.loc[[0, 1, 10], ["Title", "Price", "Bedrooms"]]
# Out:
#                                                 Title   Price    Bedrooms
# 0   M City Serviced Residence Jalan Ampang 886sf, ...  690000  2 Bedrooms
# 1   Cheapest fully furnished suria jelatek residen...  420000  3 Bedrooms
# 10  FULLY FURNISHED Suria Jelatek Residence Condo ...  420000  3 Bedrooms

# %%
df.loc[df.Price > 500000]
# Out:
#                                                   Title    Price  \
# 0     M City Serviced Residence Jalan Ampang 886sf, ...   690000
# 3     [30% Below,1037sf] Direct Subsale not Auction!...   568444
# 4     HOT area | Tiara Ampang | Near Ampang Point | ...   618000
# 8     Cheapest Suria Jelatek Residence Ampang Hilir ...   525000
# 9     1865sf LAKE VIEW Impiana On The Waterfront Con...   680000
# ...                                                 ...      ...
# 7771  [FOR SALE] THE VEO MELAWATI|FREEHOLD|2 carpark...  1000000
# 7783  [RENOVATED] 3 Residen Condominium, Desa Melawa...   580000
# 7785  [FOR SALE]SERINI MELAWATI|3BED 2BATH|FREEHOLD|...   630000
# 7787  [Serini Condominium Taman Melawati] NICE VIEW!...   585000
# 7789                                    Serini for sale   595000
#
#                 Area    Category         Size    Bedrooms    Bathrooms
# 0             AMPANG  Apartments   886 sq.ft.  2 Bedrooms  2 Bathrooms
# ...

# %%
df["Bedrooms"].str.replace("Bedrooms","Bedroom")
# Out:
# 0       2 Bedroom
# 1       3 Bedroom
# 2       3 Bedroom
# 3       3 Bedroom
# 4       4 Bedroom
#           ...
# 7786    2 Bedroom
# 7787    2 Bedroom
# 7788    3 Bedroom
# 7789    2 Bedroom
# 7790    1 Bedroom
# Name: Bedrooms, Length: 7791, dtype: object

# %%
df["Bedrooms"].str.replace(r"Bedrooms?|Bedroom", "", regex=True).str.strip()
# Out:
# 0       2
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 7786    2
# 7787    2
# 7788    3
# 7789    2
# 7790    1
# Name: Bedrooms, Length: 7791, dtype: object

# %%
df["Bathrooms"].str.replace(r"Bathrooms?|Bathroom", "", regex=True).str.strip()
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7786    1
# 7787    2
# 7788    2
# 7789    2
# 7790    1
# Name: Bathrooms, Length: 7791, dtype: object

# %%
df["Bathrooms"]
# Out:
# 0       2 Bathrooms
# 1       2 Bathrooms
# 2       2 Bathrooms
# 3       2 Bathrooms
# 4       2 Bathrooms
#            ...
# 7786     1 Bathroom
# 7787    2 Bathrooms
# 7788    2 Bathrooms
# 7789    2 Bathrooms
# 7790     1 Bathroom
# Name: Bathrooms, Length: 7791, dtype: object

# %%
df["Bathrooms"]=df["Bathrooms"].str.replace(r"Bathrooms?|Bathroom", "", regex=True).str.strip()

# %%
df["Bathrooms"]
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7786    1
# 7787    2
# 7788    2
# 7789    2
# 7790    1
# Name: Bathrooms, Length: 7791, dtype: object

# %%
df["Bedrooms"]=df["Bedrooms"].str.replace(r"Bedrooms?|Bedroom", "", regex=True).str.strip()

# %%
df["Bedrooms"]
# Out:
# 0       2
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 7786    2
# 7787    2
# 7788    3
# 7789    2
# 7790    1
# Name: Bedrooms, Length: 7791, dtype: object

# %%
df.loc[df.Area.notnull()]
# Out:
#                                                   Title   Price  \
# 0     M City Serviced Residence Jalan Ampang 886sf, ...  690000
# 1     Cheapest fully furnished suria jelatek residen...  420000
# 2     3bed 2bath Suria Jelatek Condo 5 min to LRT an...  420000
# 3     [30% Below,1037sf] Direct Subsale not Auction!...  568444
# 4     HOT area | Tiara Ampang | Near Ampang Point | ...  618000
# ...                                                 ...     ...
# 7786  [FIRE SALE]SERINI MELAWATI|STUDIO|FREEHOLD|the...  390000
# 7787  [Serini Condominium Taman Melawati] NICE VIEW!...  585000
# 7788  (STRATA!!) Desaku 3 Condominium, Taman Melawat...  310000
# 7789                                    Serini for sale  595000
# 7790    Gaya, Studio Unit, near Melawati Mall for sale.  360000
#
#                 Area    Category         Size Bedrooms Bathrooms
# 0             AMPANG  Apartments   886 sq.ft.        2         2
# 1             AMPANG  Apartments   858 sq.ft.        3         2
# ...

# %%
df.iloc[-10:]
# Out:
#                                                   Title   Price  \
# 7781  [[GROUND FLOOR]] Apartment Pesona Villa Kemens...  360000
# 7782  FACING KL, RENO | Saville Melawati Service Res...  450000
# 7783  [RENOVATED] 3 Residen Condominium, Desa Melawa...  580000
# 7784       (FREEHOLD) DESAKU 3 CONDOMINI Taman Melawati  310000
# 7785  [FOR SALE]SERINI MELAWATI|3BED 2BATH|FREEHOLD|...  630000
# 7786  [FIRE SALE]SERINI MELAWATI|STUDIO|FREEHOLD|the...  390000
# 7787  [Serini Condominium Taman Melawati] NICE VIEW!...  585000
# 7788  (STRATA!!) Desaku 3 Condominium, Taman Melawat...  310000
# 7789                                    Serini for sale  595000
# 7790    Gaya, Studio Unit, near Melawati Mall for sale.  360000
#
#                 Area    Category         Size Bedrooms Bathrooms
# 7781  TAMAN MELAWATI  Apartments   856 sq.ft.        3         2
# 7782  TAMAN MELAWATI  Apartments  1007 sq.ft.        3         2
# 7783  TAMAN MELAWATI  Apartments  1209 sq.ft.        3         2
# ...

# %%
df.to_csv("chapter2.csv", index="False")
