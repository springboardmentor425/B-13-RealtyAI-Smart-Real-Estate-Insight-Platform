# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
#checking if any missing values

df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
# checking duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe(include = 'all')
# Out:
#                        date         price     bedrooms    bathrooms  \
# count                  4600  4.600000e+03  4600.000000  4600.000000
# unique                   70           NaN          NaN          NaN
# top     2014-06-23 00:00:00           NaN          NaN          NaN
# freq                    142           NaN          NaN          NaN
# mean                    NaN  5.519630e+05     3.400870     2.160815
# std                     NaN  5.638347e+05     0.908848     0.783781
# min                     NaN  0.000000e+00     0.000000     0.000000
# 25%                     NaN  3.228750e+05     3.000000     1.750000
# 50%                     NaN  4.609435e+05     3.000000     2.250000
# 75%                     NaN  6.549625e+05     4.000000     2.500000
# max                     NaN  2.659000e+07     9.000000     8.000000
#
#          sqft_living      sqft_lot       floors   waterfront         view  \
# count    4600.000000  4.600000e+03  4600.000000  4600.000000  4600.000000
# ...

# %%
#encoding date column

df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

df = df.drop(columns=['date'])

# %%
df.head(10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
# 5   490000.0       2.0       1.00          880      6380     1.0           0
# 6   335000.0       2.0       2.00         1350      2560     1.0           0
# 7   482000.0       4.0       2.50         2710     35868     2.0           0
# 8   452500.0       3.0       2.50         2430     88426     1.0           0
# 9   640000.0       4.0       2.00         1520      6200     1.5           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
df = df.drop(columns=['day', 'month'], errors='ignore')

df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country  year
# ...

# %%
df['street'].nunique()
# Out:
# 4525

# %%
df = df.drop(columns=['street'])
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city', 'statezip', 'country', 'year'],
#       dtype='object')

# %%
df['city'].nunique()
# Out:
# 44

# %%
city_freq = df['city'].value_counts()
df['city'] = df['city'].map(city_freq)

# %%
df[['city']].head()
# Out:
#    city
# 0   123
# 1  1573
# 2   185
# 3   286
# 4   235

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  city  \
# 0     0          3        1340              0      1955          2005   123
# 1     4          5        3370            280      1921             0  1573
# 2     0          4        1930              0      1966             0   185
# 3     0          4        1000           1000      1963             0   286
# 4     0          4        1140            800      1976          1992   235
#
#    statezip country  year
# ...

# %%
#Encoding statezip Values

df['statezip'].nunique()
# Out:
# 77

# %%
df['statezip'].value_counts().head()
# Out:
# statezip
# WA 98103    148
# WA 98052    135
# WA 98117    132
# WA 98115    130
# WA 98006    110
# Name: count, dtype: int64

# %%
#!pip install category_encoders

# %%
import category_encoders as ce

# Define encoder
encoder = ce.TargetEncoder(cols=['statezip'])

# Fit and transform
df['statezip'] = encoder.fit_transform(df['statezip'], df['price'])

# %%
df[['statezip', 'price']].head()
# Out:
#         statezip      price
# 0  374553.080247   313000.0
# 1  895536.950860  2384000.0
# 2  320321.675575   342000.0
# 3  600544.375179   420000.0
# 4  637554.852314   550000.0

# %%
#Encoding country


df['country'].nunique()
# Out:
# 1

# %%
df["country_encoded"] = 1
print(df.drop(columns = ['country'], inplace = True))
# Out:
# None

# %%
df.head(10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
# 5   490000.0       2.0       1.00          880      6380     1.0           0
# 6   335000.0       2.0       2.00         1350      2560     1.0           0
# 7   482000.0       4.0       2.50         2710     35868     2.0           0
# 8   452500.0       3.0       2.50         2430     88426     1.0           0
# 9   640000.0       4.0       2.00         1520      6200     1.5           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  city  \
# ...

# %% [markdown]
# DETECTING THE OUTLIERS

# %%
import matplotlib.pyplot as plt

plt.figure()
df.boxplot(column='price')
plt.title("Boxplot of Price (Before Removing Outliers)")
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower Bound:", lower)
print("Upper Bound:", upper)
# Out:
# Lower Bound: -175256.25
# Upper Bound: 1153093.75

# %%
outliers = df[(df['price'] < lower) | (df['price'] > upper)]

print("Number of Outliers:", outliers.shape[0])
# Out:
# Number of Outliers: 240

# %%
df = df[(df['price'] >= lower) & (df['price'] <= upper)]

print("New Shape After Removing Outliers:", df.shape)
# Out:
# New Shape After Removing Outliers: (4360, 17)

# %%
plt.figure()
df.boxplot(column='price')
plt.title("Boxplot of Price (After Removing Outliers)")
plt.show()

# %%
# followed by sqft_living, sqft_lot 


plt.figure()
df.boxplot(column='sqft_living')
plt.title("sqft_living (Before)")
plt.show()

# %%
Q1 = df['sqft_living'].quantile(0.25)
Q3 = df['sqft_living'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower:", lower)
print("Upper:", upper)

outliers = df[(df['sqft_living'] < lower) | (df['sqft_living'] > upper)]
print("Outliers:", outliers.shape[0])
# Out:
# Lower: -180.0
# Upper: 4140.0
# Outliers: 76

# %%
df = df[(df['sqft_living'] >= lower) & (df['sqft_living'] <= upper)]
print("Shape after removing:", df.shape)
# Out:
# Shape after removing: (4284, 17)

# %%
plt.figure()
df.boxplot(column='sqft_living')
plt.title("sqft_living (After)")
plt.show()

# %%
#sqft_lot

plt.figure()
df.boxplot(column='sqft_lot')
plt.title("sqft_lot (Before)")
plt.show()

Q1 = df['sqft_lot'].quantile(0.25)
Q3 = df['sqft_lot'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower:", lower)
print("Upper:", upper)

outliers = df[(df['sqft_lot'] < lower) | (df['sqft_lot'] > upper)]
print("Outliers:", outliers.shape[0])

df = df[(df['sqft_lot'] >= lower) & (df['sqft_lot'] <= upper)]
print("Shape after removing:", df.shape)

plt.figure()
df.boxplot(column='sqft_lot')
plt.title("sqft_lot (After)")
plt.show()
# Out:
# Lower: -3202.0
# Upper: 18670.0
# Outliers: 486
# Shape after removing: (3798, 17)

# %%
df.head(10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
# 5   490000.0       2.0       1.00          880      6380     1.0           0
# 6   335000.0       2.0       2.00         1350      2560     1.0           0
# 9   640000.0       4.0       2.00         1520      6200     1.5           0
# 10  463000.0       3.0       1.75         1710      7320     1.0           0
# 12  588500.0       3.0       1.75         2330     14892     1.0           0
# 13  365000.0       3.0       1.00         1090      6435     1.0           0
#
#     view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  city  \
# ...

# %% [markdown]
# # Dataset After Preprocessing
#
# ### 1️⃣ Categorical Columns
#
# - Original categorical columns: `street`, `city`, `country`, `statezip`, and `date`.
# -
# - Preprocessing steps:
#   - `street` → completely dropped (unique values, not useful)
#   - `date` → split into year, month, day, then day and month dropped
#   - `city` → frequency encoding
#   - `statezip` → target encoding
#   - `country` → only one value, manually set to 1
#
# ---
#
# ### 2️⃣ Outlier Handling
#
# - Checked continuous numeric columns for outliers.
# - Outliers **removed using 1.5 × IQR method** for:
#   - `price`
#   - `sqft_living`
#   - `sqft_lot`
# - Other continuous columns (`sqft_basement`, `bathrooms`, etc.) were checked but not removed because values were not extremely different from the rest of the data.
#
# ---
#
# ### 3️⃣ Final Dataset
#
# - Unnecessary columns (`street`, day & month from date) dropped
# - Encoded categorical columns ready for modeling
# - Continuous variables cleaned for extreme outliers
#
# ---
#
# ### 4️⃣ Notes
#
# - Frequency and target encoding ensures categorical variables are numeric and usable in models.
# - Boxplots and IQR method were used to visually inspect and remove extreme outliers.
# - Dataset is now clean, consistent, and ready for further analysis or modeling.

# %%
cols = ['price', 'sqft_living', 'sqft_lot']

for col in cols:
    plt.figure(figsize=(10,4))
    df[col].head(50).plot(kind='bar')
    plt.title(f"Original {col}")
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
df[[f"{col}_scaled" for col in cols]] = scaler.fit_transform(df[cols])

# %%
df[cols + [f"{col}_scaled" for col in cols]].head()
# Out:
#       price  sqft_living  sqft_lot  price_scaled  sqft_living_scaled  \
# 0  313000.0         1340      7912     -0.738048           -0.833261
# 2  342000.0         1930     11947     -0.601042           -0.003645
# 3  420000.0         2000      8030     -0.232543            0.094784
# 4  550000.0         1940     10500      0.381621            0.010416
# 5  490000.0          880      6380      0.098161           -1.480081
#
#    sqft_lot_scaled
# 0         0.203026
# 2         1.351127
# 3         0.236601
# 4         0.939404
# 5        -0.232882

# %%
df[cols + [f"{col}_scaled" for col in cols]].head().round(3)
# Out:
#       price  sqft_living  sqft_lot  price_scaled  sqft_living_scaled  \
# 0  313000.0         1340      7912        -0.738              -0.833
# 2  342000.0         1930     11947        -0.601              -0.004
# 3  420000.0         2000      8030        -0.233               0.095
# 4  550000.0         1940     10500         0.382               0.010
# 5  490000.0          880      6380         0.098              -1.480
#
#    sqft_lot_scaled
# 0            0.203
# 2            1.351
# 3            0.237
# 4            0.939
# 5           -0.233

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

df["price"].head(30).plot(kind="bar", ax=axes[0], color="skyblue")
axes[0].set_title("Price")

df["price_scaled"].head(30).plot(kind="bar", ax=axes[1], color="orange")
axes[1].set_title("Price Scaled")

plt.tight_layout()
#plt.savefig("combined_plot.png")
plt.show()

# %%
#MinMax Scaling

from sklearn.preprocessing import MinMaxScaler

num_cols = [
    'price',
    'sqft_living',
    'sqft_lot',
]

# %%
minmax = MinMaxScaler()

df[num_cols] = minmax.fit_transform(df[num_cols])

# %%
df[num_cols].describe().round(3)
# Out:
#           price  sqft_living  sqft_lot
# count  3798.000     3798.000  3798.000
# mean      0.408        0.414     0.364
# std       0.184        0.189     0.195
# min       0.000        0.000     0.000
# 25%       0.269        0.273     0.229
# 50%       0.378        0.395     0.361
# 75%       0.517        0.536     0.480
# max       1.000        1.000     1.000
