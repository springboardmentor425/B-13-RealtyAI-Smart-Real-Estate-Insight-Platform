# %%
import pandas as pd
city_df = pd.read_csv('/home/sukesh/Desktop/RealtyAI/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/dataset/City_time_series.csv')

# %%
city_df.RegionName.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
city_df.dtypes
# Out:
# Date                                        str
# RegionName                                  str
# InventorySeasonallyAdjusted_AllHomes    float64
# InventoryRaw_AllHomes                   float64
# MedianListingPricePerSqft_1Bedroom      float64
#                                          ...
# ZRI_AllHomes                            float64
# ZRI_AllHomesPlusMultifamily             float64
# ZriPerSqft_AllHomes                     float64
# Zri_MultiFamilyResidenceRental          float64
# Zri_SingleFamilyResidenceRental         float64
# Length: 81, dtype: object

# %%
city_df.InventorySeasonallyAdjusted_AllHomes.dtype
# Out:
# dtype('float64')

# %%
city_df.InventorySeasonallyAdjusted_AllHomes.astype('float64')
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#            ...
# 3762561    26.0
# 3762562     NaN
# 3762563     NaN
# 3762564    15.0
# 3762565     NaN
# Name: InventorySeasonallyAdjusted_AllHomes, Length: 3762566, dtype: float64

# %%
city_df[pd.isnull(city_df.InventorySeasonallyAdjusted_AllHomes)]
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762557  2017-12-31           zioncentrepa
# 3762560  2017-12-31     zionvillewatauganc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# ...

# %%
city_df.InventorySeasonallyAdjusted_AllHomes.fillna("unknown")
# Out:
# 0          unknown
# 1          unknown
# 2          unknown
# 3          unknown
# 4          unknown
#             ...
# 3762561       26.0
# 3762562    unknown
# 3762563    unknown
# 3762564       15.0
# 3762565    unknown
# Name: InventorySeasonallyAdjusted_AllHomes, Length: 3762566, dtype: object

# %%
city_df.RegionName.replace('abbottstownadamspa', 'abbottstown-adamstown-pa')
# Out:
# 0          abbottstown-adamstown-pa
# 1                 aberdeenbinghamid
# 2                 aberdeenharfordmd
# 3                  aberdeenmonroems
# 4                   aberdeenmoorenc
#                      ...
# 3762561         zirconiahendersonnc
# 3762562       zolfo_springshardeefl
# 3762563       zumbro_fallswabashamn
# 3762564           zumbrotagoodhuemn
# 3762565         zuniisle_of_wightva
# Name: RegionName, Length: 3762566, dtype: str

# %% [markdown]
# # Real Estate Data Analysis Workflow
#
# ## Overview
# This notebook processes and analyzes real estate time series data from the City_time_series.csv file.
#
# ## Data Loading
# The dataset is loaded into a pandas DataFrame from the CSV file located at `/home/sukesh/Desktop/RealtyAI/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/dataset/City_time_series.csv`.
#
# ## Data Exploration
#
# ### Data Types Inspection
# - Checked the data type of `RegionName` column
# - Reviewed all column data types using `dtypes`
# - Examined the data type of `InventorySeasonallyAdjusted_AllHomes` column
#
# ### Data Quality Assessment
#
# #### Missing Values
# Identified missing values in the `InventorySeasonallyAdjusted_AllHomes` column by filtering null entries.
#
# #### Data Cleaning Tasks
#
# 1. **Convert to Numeric Type**: Converted `InventorySeasonallyAdjusted_AllHomes` to float64 for numerical analysis
#
# 2. **Handle Missing Values**: Filled null values in `InventorySeasonallyAdjusted_AllHomes` with "unknown" placeholder
#
# 3. **Standardize Region Names**: Fixed inconsistent region name formatting by replacing 'abbottstownadamspa' with the properly formatted 'abbottstown-adamstown-pa'
#
# ## Next Steps
# Further analysis and visualization of the cleaned real estate data can be performed for insights into inventory trends and regional patterns.
