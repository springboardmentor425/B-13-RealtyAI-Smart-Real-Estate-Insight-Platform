# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
reviews = pd.read_csv("C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv", index_col=0)

# %%
reviews.rename(columns={'price': 'floors'})
# Out:
#                         floors  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# ...                        ...       ...        ...          ...       ...
# 2014-07-10 00:00:00   203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00   220600.0       3.0        2.5         1490      8102
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# ...                        ...       ...        ...          ...       ...
# 2014-07-10 00:00:00   203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00   220600.0       3.0        2.5         1490      8102
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields                   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# wines
# 2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# ...                        ...       ...        ...          ...       ...
# 2014-07-10 00:00:00   203400.0       4.0        2.0         2090      6630
# 2014-07-10 00:00:00   220600.0       3.0        2.5         1490      8102
#
# fields               floors  waterfront  view  condition  sqft_above  \
# wines
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# ...                     ...         ...   ...        ...         ...
# 2014-07-10 00:00:00     1.0           0     0          3        1070
# 2014-07-10 00:00:00     2.0           0     0          4        1490
#
# fields               sqft_basement  yr_built  yr_renovated  \
# wines
# ...

# %%
canadian_youtube = pd.read_csv("C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv")
british_youtube = pd.read_csv("C:\\Users\\ruchi\\OneDrive\\Desktop\\data.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000.0       3.0        1.5         1340
# 1     2014-05-02 00:00:00  2384000.0       5.0        2.5         3650
# ...                   ...        ...       ...        ...          ...
# 4598  2014-07-10 00:00:00   203400.0       4.0        2.0         2090
# 4599  2014-07-10 00:00:00   220600.0       3.0        2.5         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# ...        ...     ...         ...   ...        ...         ...
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                street       city  \
# ...

# %%
left = canadian_youtube.set_index(['city', 'street'])
right = british_youtube.set_index(['city', 'street'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                            date_CAN  price_CAN  bedrooms_CAN  \
# city      street
# Shoreline 18810 Densmore Ave N  2014-05-02 00:00:00   313000.0           3.0
# Seattle   709 W Blaine St       2014-05-02 00:00:00  2384000.0           5.0
# ...                                             ...        ...           ...
#           5148 S Creston St     2014-07-10 00:00:00   203400.0           4.0
# Covington 18717 SE 258th St     2014-07-10 00:00:00   220600.0           3.0
#
#                                 bathrooms_CAN  sqft_living_CAN  sqft_lot_CAN  \
# city      street
# Shoreline 18810 Densmore Ave N            1.5             1340          7912
# Seattle   709 W Blaine St                 2.5             3650          9050
# ...                                       ...              ...           ...
#           5148 S Creston St               2.0             2090          6630
# Covington 18717 SE 258th St               2.5             1490          8102
#
# ...
