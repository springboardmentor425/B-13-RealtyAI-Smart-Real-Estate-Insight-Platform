# %%
import pandas as pd
housing = pd.read_csv("C:/Users/munur/Documents/GitHub/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/datasets/real_estate_dataset.csv")
pd.set_option('display.max_rows', 5)

# %%
housing.price.dtype
# Out:
# dtype('float64')

# %%
housing.dtypes
# Out:
# url                 str
# beds              int64
#                  ...
# price           float64
# neighborhood        str
# Length: 9, dtype: object

# %%
housing.beds.astype('float64')
# Out:
# 0      0.0
# 1      2.0
#       ...
# 285    1.0
# 286    3.0
# Name: beds, Length: 287, dtype: float64

# %%
housing.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# -Missing data

# %%
housing[pd.isnull(housing.city)]
# Out:
# Empty DataFrame
# Columns: [url, beds, city, date, size, type, baths, price, neighborhood]
# Index: []

# %%
housing.url.fillna("Unknown")
# Out:
# 0      https://www.99acres.com/residential-land-plot-...
# 1      https://www.99acres.com/2-bhk-bedroom-apartmen...
#                              ...
# 285    https://www.99acres.com/1-bhk-bedroom-apartmen...
# 286    https://www.99acres.com/3-bhk-bedroom-apartmen...
# Name: url, Length: 287, dtype: str

# %%
housing.neighborhood.replace("Whitefield", "white")
# Out:
# 0           Jigani
# 1      Tumkur Road
#           ...
# 285     Kirkatwadi
# 286      Mahalunge
# Name: neighborhood, Length: 287, dtype: str
