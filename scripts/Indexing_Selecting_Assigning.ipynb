# %%
import pandas as pd
housing = pd.read_csv("C:/Users/munur/Documents/GitHub/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/datasets/real_estate_dataset.csv")
pd.set_option('display.max_rows', 5)

# %%
housing
# Out:
#                                                    url  beds       city  \
# 0    https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# ..                                                 ...   ...        ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date           size                     type  baths       price  \
# 0    2025-02-19  799-1258 sqft  Residential land / Plot      0   2317000.0
# 1    2025-02-19      1085 sqft               2 BHK Flat      2  12500000.0
# ..          ...            ...                      ...    ...         ...
# 285  2025-02-17       640 sqft    Residential apartment      1   3500000.0
# 286  2025-02-12       878 sqft    Residential apartment      3  12000000.0
#
#     neighborhood
# 0         Jigani
# 1    Tumkur Road
# ..           ...
# ...

# %%
housing.city
# Out:
# 0      Bangalore
# 1      Bangalore
#          ...
# 285         Pune
# 286         Pune
# Name: city, Length: 287, dtype: str

# %%
housing['city'][0]
# Out:
# 'Bangalore'

# %% [markdown]
# -Indexing in pandas

# %%
housing.iloc[0]
# Out:
# url             https://www.99acres.com/residential-land-plot-...
# beds                                                            0
#                                       ...
# price                                                   2317000.0
# neighborhood                                               Jigani
# Name: 0, Length: 9, dtype: object

# %%
housing.iloc[:, 0]
# Out:
# 0      https://www.99acres.com/residential-land-plot-...
# 1      https://www.99acres.com/2-bhk-bedroom-apartmen...
#                              ...
# 285    https://www.99acres.com/1-bhk-bedroom-apartmen...
# 286    https://www.99acres.com/3-bhk-bedroom-apartmen...
# Name: url, Length: 287, dtype: str

# %%
housing.iloc[:3, 0]
# Out:
# 0    https://www.99acres.com/residential-land-plot-...
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2    https://www.99acres.com/sumadhura-capitol-resi...
# Name: url, dtype: str

# %%
housing.iloc[1:3, 0]
# Out:
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2    https://www.99acres.com/sumadhura-capitol-resi...
# Name: url, dtype: str

# %%
housing.iloc[[0, 1, 2], 0]
# Out:
# 0    https://www.99acres.com/residential-land-plot-...
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2    https://www.99acres.com/sumadhura-capitol-resi...
# Name: url, dtype: str

# %%
housing.iloc[-5:]
# Out:
#                                                    url  beds  city  \
# 282  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
# 283  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Pune
# 284  https://www.99acres.com/6-bhk-bedroom-independ...     6  Pune
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1  Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
#
#            date      size                     type  baths       price  \
# 282  2025-01-19  840 sqft    Residential apartment      3  10000000.0
# 283  2025-02-13  690 sqft    Residential apartment      2   6500000.0
# 284  2025-01-19  840 sqft  Independent House/Villa      6  13500000.0
# 285  2025-02-17  640 sqft    Residential apartment      1   3500000.0
# 286  2025-02-12  878 sqft    Residential apartment      3  12000000.0
#
#       neighborhood
# 282  Manjari Khurd
# 283       Punawale
# 284         Katraj
# 285     Kirkatwadi
# 286      Mahalunge

# %% [markdown]
# -label based selection

# %%
housing.loc[0,'city']
# Out:
# 'Bangalore'

# %%
housing.loc[:, ['city', 'size', 'price']]
# Out:
#           city           size       price
# 0    Bangalore  799-1258 sqft   2317000.0
# 1    Bangalore      1085 sqft  12500000.0
# ..         ...            ...         ...
# 285       Pune       640 sqft   3500000.0
# 286       Pune       878 sqft  12000000.0
#
# [287 rows x 3 columns]

# %% [markdown]
# -Manipulating the index

# %%
housing.set_index("city")
# Out:
#                                                          url  beds  \
# city
# Bangalore  https://www.99acres.com/residential-land-plot-...     0
# Bangalore  https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# ...                                                      ...   ...
# Pune       https://www.99acres.com/1-bhk-bedroom-apartmen...     1
# Pune       https://www.99acres.com/3-bhk-bedroom-apartmen...     3
#
#                  date           size                     type  baths  \
# city
# Bangalore  2025-02-19  799-1258 sqft  Residential land / Plot      0
# Bangalore  2025-02-19      1085 sqft               2 BHK Flat      2
# ...               ...            ...                      ...    ...
# Pune       2025-02-17       640 sqft    Residential apartment      1
# Pune       2025-02-12       878 sqft    Residential apartment      3
#
#                 price neighborhood
# city
# Bangalore   2317000.0       Jigani
# Bangalore  12500000.0  Tumkur Road
# ...

# %% [markdown]
# -conditional selection

# %%
housing.city == 'Pune'
# Out:
# 0      False
# 1      False
#        ...
# 285     True
# 286     True
# Name: city, Length: 287, dtype: bool

# %%
housing.loc[housing.city=='Pune']
# Out:
#                                                    url  beds  city  \
# 278  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
# 279  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Pune
# ..                                                 ...   ...   ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1  Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
#
#            date       size                   type  baths       price  \
# 278  2025-02-18  1510 sqft  Residential apartment      3  16000000.0
# 279  2025-01-19  1075 sqft  Residential apartment      2  13000000.0
# ..          ...        ...                    ...    ...         ...
# 285  2025-02-17   640 sqft  Residential apartment      1   3500000.0
# 286  2025-02-12   878 sqft  Residential apartment      3  12000000.0
#
#      neighborhood
# 278      Ghorpadi
# 279  Sinhgad Road
# ..            ...
# 285    Kirkatwadi
# 286     Mahalunge
#
# [9 rows x 9 columns]

# %%
housing.loc[(housing.city == 'Pune') & (housing.beds >= 3)]
# Out:
#                                                    url  beds  city  \
# 278  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
# 280  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
# 282  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
# 284  https://www.99acres.com/6-bhk-bedroom-independ...     6  Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  Pune
#
#            date       size                     type  baths       price  \
# 278  2025-02-18  1510 sqft    Residential apartment      3  16000000.0
# 280  2025-02-05  1150 sqft    Residential apartment      2   9500000.0
# 282  2025-01-19   840 sqft    Residential apartment      3  10000000.0
# 284  2025-01-19   840 sqft  Independent House/Villa      6  13500000.0
# 286  2025-02-12   878 sqft    Residential apartment      3  12000000.0
#
#       neighborhood
# 278       Ghorpadi
# 280          Undri
# 282  Manjari Khurd
# 284         Katraj
# 286      Mahalunge

# %%
housing.loc[(housing.city == 'Pune') | (housing.beds >= 3)]
# Out:
#                                                    url  beds       city  \
# 2    https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 7    https://www.99acres.com/keya-life-by-the-lake-...     4  Bangalore
# ..                                                 ...   ...        ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date            size                   type  baths       price  \
# 2    2025-02-19  1525-2150 sqft     3, 4 BHK Apartment      0  23200000.0
# 7    2025-02-19          0 sqft         4, 5 BHK Villa      0  39800000.0
# ..          ...             ...                    ...    ...         ...
# 285  2025-02-17        640 sqft  Residential apartment      1   3500000.0
# 286  2025-02-12        878 sqft  Residential apartment      3  12000000.0
#
#     neighborhood
# 2     Whitefield
# 7         Hebbal
# ..           ...
# ...

# %%
housing.loc[housing.city.isin(['Bangalore', 'Pune'])]
# Out:
#                                                    url  beds       city  \
# 0    https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# ..                                                 ...   ...        ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date           size                     type  baths       price  \
# 0    2025-02-19  799-1258 sqft  Residential land / Plot      0   2317000.0
# 1    2025-02-19      1085 sqft               2 BHK Flat      2  12500000.0
# ..          ...            ...                      ...    ...         ...
# 285  2025-02-17       640 sqft    Residential apartment      1   3500000.0
# 286  2025-02-12       878 sqft    Residential apartment      3  12000000.0
#
#     neighborhood
# 0         Jigani
# 1    Tumkur Road
# ..           ...
# ...

# %%
housing.loc[housing.price.notnull()]
# Out:
#                                                    url  beds       city  \
# 0    https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# ..                                                 ...   ...        ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date           size                     type  baths       price  \
# 0    2025-02-19  799-1258 sqft  Residential land / Plot      0   2317000.0
# 1    2025-02-19      1085 sqft               2 BHK Flat      2  12500000.0
# ..          ...            ...                      ...    ...         ...
# 285  2025-02-17       640 sqft    Residential apartment      1   3500000.0
# 286  2025-02-12       878 sqft    Residential apartment      3  12000000.0
#
#     neighborhood
# 0         Jigani
# 1    Tumkur Road
# ..           ...
# ...

# %% [markdown]
# -Assigning data

# %%
housing['critic'] = 'everyone'
housing['critic']
# Out:
# 0      everyone
# 1      everyone
#          ...
# 285    everyone
# 286    everyone
# Name: critic, Length: 287, dtype: str

# %%
housing['index_backwards'] = range(len(housing), 0, -1)
housing['index_backwards']
# Out:
# 0      287
# 1      286
#       ...
# 285      2
# 286      1
# Name: index_backwards, Length: 287, dtype: int64
