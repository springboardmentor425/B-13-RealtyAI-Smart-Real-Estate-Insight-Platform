# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.7 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.7 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.7 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.7 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.7 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.7 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.7 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.7 MB 963.7 kB/s eta 0:00:08
# ...

# %%
import pandas as pd
