# %% [markdown]
# -Renaming

# %%
import pandas as pd
housing = pd.read_csv("C:/Users/munur/Documents/GitHub/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/datasets/real_estate_dataset.csv")
pd.set_option('display.max_rows', 5)

# %%
housing.rename(columns={'beds': 'bedrooms'})
# Out:
#                                                    url  bedrooms       city  \
# 0    https://www.99acres.com/residential-land-plot-...         0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...         2  Bangalore
# ..                                                 ...       ...        ...
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...         1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...         3       Pune
#
#            date           size                     type  baths       price  \
# 0    2025-02-19  799-1258 sqft  Residential land / Plot      0   2317000.0
# 1    2025-02-19      1085 sqft               2 BHK Flat      2  12500000.0
# ..          ...            ...                      ...    ...         ...
# 285  2025-02-17       640 sqft    Residential apartment      1   3500000.0
# 286  2025-02-12       878 sqft    Residential apartment      3  12000000.0
#
#     neighborhood
# 0         Jigani
# 1    Tumkur Road
# ...

# %%
housing.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                                                            url  beds  \
# firstEntry   https://www.99acres.com/residential-land-plot-...     0
# secondEntry  https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# ...                                                        ...   ...
# 285          https://www.99acres.com/1-bhk-bedroom-apartmen...     1
# 286          https://www.99acres.com/3-bhk-bedroom-apartmen...     3
#
#                   city        date           size                     type  \
# firstEntry   Bangalore  2025-02-19  799-1258 sqft  Residential land / Plot
# secondEntry  Bangalore  2025-02-19      1085 sqft               2 BHK Flat
# ...                ...         ...            ...                      ...
# 285               Pune  2025-02-17       640 sqft    Residential apartment
# 286               Pune  2025-02-12       878 sqft    Residential apartment
#
#              baths       price neighborhood
# firstEntry       0   2317000.0       Jigani
# ...

# %%
housing.rename_axis("numbers", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields                                                 url  beds       city  \
# numbers
# 0        https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1        https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# ...                                                    ...   ...        ...
# 285      https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286      https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
# fields         date           size                     type  baths  \
# numbers
# 0        2025-02-19  799-1258 sqft  Residential land / Plot      0
# 1        2025-02-19      1085 sqft               2 BHK Flat      2
# ...             ...            ...                      ...    ...
# 285      2025-02-17       640 sqft    Residential apartment      1
# 286      2025-02-12       878 sqft    Residential apartment      3
#
# fields        price neighborhood
# numbers
# 0         2317000.0       Jigani
# ...

# %% [markdown]
# -Combining

# %%
housing.head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %%
#Combining Data
#Concatenate (Row-wise Combine)
data1 = housing.head(100)
data2 = housing.tail(100)
combined_data = pd.concat([data1, data2])

# %%
combined_data.head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere
