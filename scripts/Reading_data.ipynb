# %%
import pandas as pd

# %%
house_price_data= pd.read_csv("C:/Users/munur/Documents/GitHub/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/datasets/real_estate_dataset.csv")

# %%
house_price_data.shape
# Out:
# (287, 9)

# %%
house_price_data.head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %%
house_price_data= pd.read_csv("C:/Users/munur/Documents/GitHub/B-13-RealtyAI-Smart-Real-Estate-Insight-Platform/datasets/real_estate_dataset.csv",index_col=0)
house_price_data.head()
# Out:
#                                                     beds       city  \
# url
# https://www.99acres.com/residential-land-plot-f...     0  Bangalore
# https://www.99acres.com/2-bhk-bedroom-apartment...     2  Bangalore
# https://www.99acres.com/sumadhura-capitol-resid...     3  Bangalore
# https://www.99acres.com/provident-botanico-souk...     2  Bangalore
# https://www.99acres.com/kvg-superior-kalkere-ba...     2  Bangalore
#
#                                                           date  \
# url
# https://www.99acres.com/residential-land-plot-f...  2025-02-19
# https://www.99acres.com/2-bhk-bedroom-apartment...  2025-02-19
# https://www.99acres.com/sumadhura-capitol-resid...  2025-02-19
# https://www.99acres.com/provident-botanico-souk...  2025-02-19
# https://www.99acres.com/kvg-superior-kalkere-ba...  2025-02-19
#
#                                                               size  \
# url
# https://www.99acres.com/residential-land-plot-f...   799-1258 sqft
# ...
