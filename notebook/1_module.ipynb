# %%
import pandas as pd

# %%
pd.DataFrame({
    "City": ["Hyderabad", "Chennai"],
    "Price": [5000000, 4500000]
})
# Out:
#         City    Price
# 0  Hyderabad  5000000
# 1    Chennai  4500000

# %%
pd.DataFrame(
    {
        "Price": [5000000, 4500000],
        "Bedrooms": [3, 2]
    },
    index=["House1", "House2"]
)
# Out:
#           Price  Bedrooms
# House1  5000000         3
# House2  4500000         2

# %%
pd.Series(
    [5000000, 4500000, 6000000, 5200000],
    index=["Hyderabad", "Chennai", "Mumbai", "Bangalore"]
)
# Out:
# Hyderabad    5000000
# Chennai      4500000
# Mumbai       6000000
# Bangalore    5200000
# dtype: int64

# %%
df = pd.read_csv("../dataset/housing_price.csv")

# %%
df.head()
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 1        2012            12              4.2                      8
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
# 4        2014            10              4.3                      9
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.shape
# Out:
# (5, 20)
