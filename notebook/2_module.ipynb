# %%
import pandas as pd
df = pd.read_csv("../dataset/housing_price.csv")

# %%
df.head()
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 1        2012            12              4.2                      8
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
# 4        2014            10              4.3                      9
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %% [markdown]
# 5 Rows× 20 Columns

# %%
df["City"]
# Out:
# 0    Hyderabad
# 1      Chennai
# 2       Mumbai
# 3    Bangalore
# 4         Pune
# Name: City, dtype: object

# %%
df.iloc[:,[0,1,10,13,18,5,3]]
# Out:
#          Date       City  Distance_to_Center_km  Nearby_Malls Property_Type  \
# 0  2024-01-31  Hyderabad                     10             1     Apartment
# 1  2024-02-29    Chennai                      8             1     Apartment
# 2  2024-03-31     Mumbai                      5             2         Villa
# 3  2024-04-30  Bangalore                      7             1     Apartment
# 4  2024-05-31       Pune                      9             1     Apartment
#
#    Floors  Bedrooms
# 0       1         3
# 1       1         2
# 2       2         4
# 3       1         3
# 4       1         2

# %%
df.iloc[0, 1]
# Out:
# 'Hyderabad'

# %%
df.loc[0, "City"]
# Out:
# 'Hyderabad'

# %%
df[df["City"] == "Hyderabad"]
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# 0               3                 2             1         2.1            4200
#
#    Total_Price Loan_Eligible Property_Type Listing_Status
# 0      5040000           Yes     Apartment      Available

# %%
df[df["Bedrooms"] > 2]
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# 0               3                 2             1         2.1            4200
# 2               4                 3             2         1.8            6000
# 3               3                 2             1         2.0            5000
#
#    Total_Price Loan_Eligible Property_Type Listing_Status
# ...

# %%
df[df["Listing_Status"] == "Available"]
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# 0               3                 2             1         2.1            4200
# 2               4                 3             2         1.8            6000
# 3               3                 2             1         2.0            5000
#
#    Total_Price Loan_Eligible Property_Type Listing_Status
# ...

# %%
df[df["Total_Price"] > 5000000]
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# 0               3                 2             1         2.1            4200
# 2               4                 3             2         1.8            6000
# 3               3                 2             1         2.0            5000
#
#    Total_Price Loan_Eligible Property_Type Listing_Status
# ...

# %%
df["Price_in_Lakhs"] = df["Total_Price"] / 100000

# %%
df["Price_per_Sqft"] = df["Price_per_Sqft"] + 500

# %%
df["Luxury_Property"] = df["Total_Price"] > 8000000

# %%
df.head()
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  ...  Nearby_Hospitals  \
# 0        2015             9              4.5  ...                 2
# 1        2012            12              4.2  ...                 2
# 2        2018             6              4.8  ...                 3
# 3        2016             8              4.6  ...                 2
# 4        2014            10              4.3  ...                 2
#
#    Nearby_Malls  Crime_Rate  Price_per_Sqft  Total_Price  Loan_Eligible  \
# ...
