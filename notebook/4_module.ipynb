# %%
import pandas as pd

df = pd.read_csv("../dataset/housing_price.csv")

# %%
df.head()
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 0        2015             9              4.5                     10
# 1        2012            12              4.2                      8
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
# 4        2014            10              4.3                      9
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.groupby("City")["Total_Price"].mean()
# Out:
# City
# Bangalore    6500000.0
# Chennai      4500000.0
# Hyderabad    5040000.0
# Mumbai       9000000.0
# Pune         4730000.0
# Name: Total_Price, dtype: float64

# %%
df.groupby("City")["Total_Price"].count()
# Out:
# City
# Bangalore    1
# Chennai      1
# Hyderabad    1
# Mumbai       1
# Pune         1
# Name: Total_Price, dtype: int64

# %%
df.groupby("Property_Type")["Area_sqft"].mean()
# Out:
# Property_Type
# Apartment    1150.0
# Villa        1500.0
# Name: Area_sqft, dtype: float64

# %%
df.groupby("City")["Total_Price"].max()
# Out:
# City
# Bangalore    6500000
# Chennai      4500000
# Hyderabad    5040000
# Mumbai       9000000
# Pune         4730000
# Name: Total_Price, dtype: int64

# %%
df.groupby(["City", "Property_Type"])["Total_Price"].mean()
# Out:
# City       Property_Type
# Bangalore  Apartment        6500000.0
# Chennai    Apartment        4500000.0
# Hyderabad  Apartment        5040000.0
# Mumbai     Villa            9000000.0
# Pune       Apartment        4730000.0
# Name: Total_Price, dtype: float64

# %%
df.sort_values("Total_Price")
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 1        2012            12              4.2                      8
# 4        2014            10              4.3                      9
# 0        2015             9              4.5                     10
# 3        2016             8              4.6                      7
# 2        2018             6              4.8                      5
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.sort_values("Total_Price", ascending=False)
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 4  2024-05-31       Pune       1100         2          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
# 0        2015             9              4.5                     10
# 4        2014            10              4.3                      9
# 1        2012            12              4.2                      8
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.sort_values("City")
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 3        2016             8              4.6                      7
# 1        2012            12              4.2                      8
# 0        2015             9              4.5                     10
# 2        2018             6              4.8                      5
# 4        2014            10              4.3                      9
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.sort_values(["City", "Total_Price"])
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 1  2024-02-29    Chennai       1000         2          2       1        1
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 4  2024-05-31       Pune       1100         2          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 3        2016             8              4.6                      7
# 1        2012            12              4.2                      8
# 0        2015             9              4.5                     10
# 2        2018             6              4.8                      5
# 4        2014            10              4.3                      9
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# ...

# %%
df.sort_values("Total_Price", ascending=False).head(3)
# Out:
#          Date       City  Area_sqft  Bedrooms  Bathrooms  Floors  Parking  \
# 2  2024-03-31     Mumbai       1500         4          3       2        2
# 3  2024-04-30  Bangalore       1300         3          2       1        1
# 0  2024-01-31  Hyderabad       1200         3          2       1        1
#
#    Year_Built  Property_Age  Location_Rating  Distance_to_Center_km  \
# 2        2018             6              4.8                      5
# 3        2016             8              4.6                      7
# 0        2015             9              4.5                     10
#
#    Nearby_Schools  Nearby_Hospitals  Nearby_Malls  Crime_Rate  Price_per_Sqft  \
# 2               4                 3             2         1.8            6000
# 3               3                 2             1         2.0            5000
# 0               3                 2             1         2.1            4200
#
#    Total_Price Loan_Eligible Property_Type Listing_Status
# ...
