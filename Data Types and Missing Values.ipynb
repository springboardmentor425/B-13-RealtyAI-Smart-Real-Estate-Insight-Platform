# %%
import pandas as pd

file_path = r"C:\Users\HARSHITHA\Downloads\price_paid_records.csv.zip"

# Load only important columns + limit rows
df = pd.read_csv(
    file_path,
    compression="zip",
    usecols=[
        "Price",
        "Date of Transfer",
        "Property Type",
        "Old/New",
        "Duration",
        "Town/City",
        "District",
        "County"
    ],
    dtype={
        "Price": "int32",
        "Property Type": "category",
        "Old/New": "category",
        "Duration": "category",
        "Town/City": "category",
        "District": "category",
        "County": "category"
    }
)

# Convert date column properly
df["Date of Transfer"] = pd.to_datetime(df["Date of Transfer"])

# Check first rows
df.head()
# Out:
#    Price Date of Transfer Property Type Old/New Duration   Town/City  \
# 0  25000       1995-08-18             T       N        F      OLDHAM
# 1  42500       1995-08-09             S       N        F       GRAYS
# 2  45000       1995-06-30             T       N        F  HIGHBRIDGE
# 3  43150       1995-11-24             T       N        F     BEDFORD
# 4  18899       1995-06-23             S       N        F   WAKEFIELD
#
#              District              County
# 0              OLDHAM  GREATER MANCHESTER
# 1            THURROCK            THURROCK
# 2           SEDGEMOOR            SOMERSET
# 3  NORTH BEDFORDSHIRE        BEDFORDSHIRE
# 4               LEEDS      WEST YORKSHIRE

# %%
df["Date of Transfer"] = pd.to_datetime(df["Date of Transfer"])
df["Date of Transfer"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.columns
# Out:
# Index(['Price', 'Date of Transfer', 'Property Type', 'Old/New', 'Duration',
#        'Town/City', 'District', 'County'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Price                        int32
# Date of Transfer    datetime64[ns]
# Property Type             category
# Old/New                   category
# Duration                  category
# Town/City                 category
# District                  category
# County                    category
# dtype: object

# %%
df.isnull().sum()
# Out:
# Price               0
# Date of Transfer    0
# Property Type       0
# Old/New             0
# Duration            0
# Town/City           0
# District            0
# County              0
# dtype: int64

# %%
(df.isnull().mean() * 100).round(2)
# Out:
# Price               0.0
# Date of Transfer    0.0
# Property Type       0.0
# Old/New             0.0
# Duration            0.0
# Town/City           0.0
# District            0.0
# County              0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22489348 entries, 0 to 22489347
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Price             int32
#  1   Date of Transfer  datetime64[ns]
#  2   Property Type     category
#  3   Old/New           category
#  4   Duration          category
#  5   Town/City         category
#  6   District          category
#  7   County            category
# dtypes: category(6), datetime64[ns](1), int32(1)
# memory usage: 450.5 MB

# %%
df["Price"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Price"].hasnans
# Out:
# False

# %%
null_summary = pd.DataFrame({
    "Null Count": df.isnull().sum(),
    "Null Percentage": (df.isnull().mean() * 100).round(2)
})

null_summary
# Out:
#                   Null Count  Null Percentage
# Price                      0              0.0
# Date of Transfer           0              0.0
# Property Type              0              0.0
# Old/New                    0              0.0
# Duration                   0              0.0
# Town/City                  0              0.0
# District                   0              0.0
# County                     0              0.0

# %%
threshold = len(df) * 0.9
df = df.dropna(thresh=threshold, axis=1)

# %%
df.isnull().sum()
# Out:
# Price               0
# Date of Transfer    0
# Property Type       0
# Old/New             0
# Duration            0
# Town/City           0
# District            0
# County              0
# dtype: int64

# %%
df.shape
# Out:
# (22489348, 8)

# %%
df.dtypes
# Out:
# Price                        int32
# Date of Transfer    datetime64[ns]
# Property Type             category
# Old/New                   category
# Duration                  category
# Town/City                 category
# District                  category
# County                    category
# dtype: object
