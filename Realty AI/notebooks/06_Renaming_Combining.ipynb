# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:/Users/dindu/OneDrive/Desktop/Realty AI/dataset/real_estate_dataset.csv")

# %%
df.head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %% [markdown]
# ## Renaming

# %%
df.rename(columns={"price": "property_price"})
# Out:
#                                                    url  beds       city  \
# 0    https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2    https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3    https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4    https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
# ..                                                 ...   ...        ...
# 282  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
# 283  https://www.99acres.com/2-bhk-bedroom-apartmen...     2       Pune
# 284  https://www.99acres.com/6-bhk-bedroom-independ...     6       Pune
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date            size                     type  baths  \
# ...

# %%
df.rename(index={0: "firstEntry", 1: "secondEntry"})
# Out:
#                                                            url  beds  \
# firstEntry   https://www.99acres.com/residential-land-plot-...     0
# secondEntry  https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# 2            https://www.99acres.com/sumadhura-capitol-resi...     3
# 3            https://www.99acres.com/provident-botanico-sou...     2
# 4            https://www.99acres.com/kvg-superior-kalkere-b...     2
# ...                                                        ...   ...
# 282          https://www.99acres.com/3-bhk-bedroom-apartmen...     3
# 283          https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# 284          https://www.99acres.com/6-bhk-bedroom-independ...     6
# 285          https://www.99acres.com/1-bhk-bedroom-apartmen...     1
# 286          https://www.99acres.com/3-bhk-bedroom-apartmen...     3
#
#                   city        date            size                     type  \
# ...

# %%
df.rename_axis("properties", axis="rows").rename_axis("fields", axis="columns")
# Out:
# fields                                                    url  beds  \
# properties
# 0           https://www.99acres.com/residential-land-plot-...     0
# 1           https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# 2           https://www.99acres.com/sumadhura-capitol-resi...     3
# 3           https://www.99acres.com/provident-botanico-sou...     2
# 4           https://www.99acres.com/kvg-superior-kalkere-b...     2
# ...                                                       ...   ...
# 282         https://www.99acres.com/3-bhk-bedroom-apartmen...     3
# 283         https://www.99acres.com/2-bhk-bedroom-apartmen...     2
# 284         https://www.99acres.com/6-bhk-bedroom-independ...     6
# 285         https://www.99acres.com/1-bhk-bedroom-apartmen...     1
# 286         https://www.99acres.com/3-bhk-bedroom-apartmen...     3
#
# fields           city        date            size                     type  \
# properties
# ...

# %% [markdown]
# ## Combining

# %%
df1 = df.iloc[:150]
df2 = df.iloc[150:]

# %%
combined = pd.concat([df1, df2])
combined.shape
# Out:
# (287, 9)

# %%
left = df.set_index(["city", "neighborhood"])
left.head()
# Out:
#                                                                       url  \
# city      neighborhood
# Bangalore Jigani        https://www.99acres.com/residential-land-plot-...
#           Tumkur Road   https://www.99acres.com/2-bhk-bedroom-apartmen...
#           Whitefield    https://www.99acres.com/sumadhura-capitol-resi...
#           Soukya Road   https://www.99acres.com/provident-botanico-sou...
#           Kalkere       https://www.99acres.com/kvg-superior-kalkere-b...
#
#                         beds        date            size  \
# city      neighborhood
# Bangalore Jigani           0  2025-02-19   799-1258 sqft
#           Tumkur Road      2  2025-02-19       1085 sqft
#           Whitefield       3  2025-02-19  1525-2150 sqft
#           Soukya Road      2  2025-02-19   658-1003 sqft
#           Kalkere          2  2025-02-19  1179-1449 sqft
#
#                                            type  baths       price
# city      neighborhood
# ...

# %%
right = df[["city", "type"]].drop_duplicates().set_index("city")
right.head()
# Out:
#                               type
# city
# Bangalore  Residential land / Plot
# Bangalore               2 BHK Flat
# Bangalore       3, 4 BHK Apartment
# Bangalore       2, 3 BHK Apartment
# Bangalore    2, 3, 4 BHK Apartment

# %%
joined = df.set_index("city").join(right, rsuffix="_right")
joined.head()
# Out:
#                                                     url  beds    date  \
# city
# Agra  https://www.99acres.com/residential-land-plot-...     0  2w ago
# Agra  https://www.99acres.com/residential-land-plot-...     0  2w ago
# Agra  https://www.99acres.com/residential-land-plot-...     0  2w ago
# Agra  https://www.99acres.com/residential-land-plot-...     0  2w ago
# Agra  https://www.99acres.com/residential-land-plot-...     0  2w ago
#
#             size                     type  baths        price neighborhood  \
# city
# Agra  99000 sqft  Residential land / Plot      0  600000000.0  Jeoni Mandi
# Agra  99000 sqft  Residential land / Plot      0  600000000.0  Jeoni Mandi
# Agra  99000 sqft  Residential land / Plot      0  600000000.0  Jeoni Mandi
# Agra  99000 sqft  Residential land / Plot      0  600000000.0  Jeoni Mandi
# Agra  99000 sqft  Residential land / Plot      0  600000000.0  Jeoni Mandi
#
#                    type_right
# city
# Agra  Residential land / Plot
# ...

# %%
city_info = pd.DataFrame({
    "city": df["city"].unique(),
    "state": ["Unknown"] * df["city"].nunique()
}).set_index("city")

joined = df.set_index("city").join(city_info)
joined.head()
# Out:
#                                                     url  beds     date  \
# city
# Agra  https://www.99acres.com/residential-land-plot-...     0   2w ago
# Agra  https://www.99acres.com/5-bhk-bedroom-independ...     5   3w ago
# Agra  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  2mo ago
# Agra  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  2mo ago
# Agra  https://www.99acres.com/3-bhk-bedroom-apartmen...     3  2mo ago
#
#             size                     type  baths        price  neighborhood  \
# city
# Agra  99000 sqft  Residential land / Plot      0  600000000.0   Jeoni Mandi
# Agra   3753 sqft          5 Bedroom House      2   41700000.0   Civil Lines
# Agra   1883 sqft               3 BHK Flat      3   11000000.0    Taj Nagari
# Agra    968 sqft               2 BHK Flat      2    5200000.0  Shastripuram
# Agra   1705 sqft               3 BHK Flat      3    8200000.0    Dayal Bagh
#
#         state
# city
# Agra  Unknown
# Agra  Unknown
# ...
