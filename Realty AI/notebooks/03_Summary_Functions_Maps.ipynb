# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:/Users/dindu/OneDrive/Desktop/Realty AI/dataset/real_estate_dataset.csv")

# %%
df.head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %% [markdown]
# ## Summary Functions

# %%
df
# Out:
#                                                    url  beds       city  \
# 0    https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1    https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2    https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3    https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4    https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
# ..                                                 ...   ...        ...
# 282  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
# 283  https://www.99acres.com/2-bhk-bedroom-apartmen...     2       Pune
# 284  https://www.99acres.com/6-bhk-bedroom-independ...     6       Pune
# 285  https://www.99acres.com/1-bhk-bedroom-apartmen...     1       Pune
# 286  https://www.99acres.com/3-bhk-bedroom-apartmen...     3       Pune
#
#            date            size                     type  baths       price  \
# ...

# %%
df.price.describe()
# Out:
# count    2.870000e+02
# mean     1.956434e+07
# std      4.461799e+07
# min      0.000000e+00
# 25%      4.738000e+06
# 50%      1.000000e+07
# 75%      2.085000e+07
# max      6.000000e+08
# Name: price, dtype: float64

# %%
df.type.describe()
# Out:
# count                         287
# unique                         48
# top       Residential land / Plot
# freq                           47
# Name: type, dtype: object

# %%
df.price.mean()
# Out:
# 19564337.69216028

# %%
df.city.value_counts()
# Out:
# city
# Kakinada         37
# Visakhapatnam    25
# Noida            22
# Hyderabad        20
# Chennai          20
# Mumbai           17
# Bangalore        10
# Agra             10
# Jaipur           10
# Delhi            10
# Gurgaon          10
# Lucknow          10
# Jalpaiguri       10
# Coimbatore       10
# Kanyakumari      10
# Gandhinagar      10
# Bhubaneswar      10
# Kochi            10
# Vijayawada        9
# Pune              9
# Patna             2
# Navi Mumbai       2
# Thane             1
# Guntur            1
# Vizianagaram      1
# Vikarabad         1
# Name: count, dtype: int64

# %%
df.city.value_counts()
# Out:
# city
# Kakinada         37
# Visakhapatnam    25
# Noida            22
# Hyderabad        20
# Chennai          20
# Mumbai           17
# Bangalore        10
# Agra             10
# Jaipur           10
# Delhi            10
# Gurgaon          10
# Lucknow          10
# Jalpaiguri       10
# Coimbatore       10
# Kanyakumari      10
# Gandhinagar      10
# Bhubaneswar      10
# Kochi            10
# Vijayawada        9
# Pune              9
# Patna             2
# Navi Mumbai       2
# Thane             1
# Guntur            1
# Vizianagaram      1
# Vikarabad         1
# Name: count, dtype: int64

# %% [markdown]
# ## Maps

# %%
beds_mean = df.beds.mean()
beds_mean
# Out:
# 2.156794425087108

# %%
df["city"].map(lambda x: x.upper())
# Out:
# 0      BANGALORE
# 1      BANGALORE
# 2      BANGALORE
# 3      BANGALORE
# 4      BANGALORE
#          ...
# 282         PUNE
# 283         PUNE
# 284         PUNE
# 285         PUNE
# 286         PUNE
# Name: city, Length: 287, dtype: object

# %%
price_mean = df.price.mean()
df.price.map(lambda p: p - price_mean)
# Out:
# 0     -1.724734e+07
# 1     -7.064338e+06
# 2      3.635662e+06
# 3     -1.867534e+07
# 4     -1.308134e+07
#            ...
# 282   -9.564338e+06
# 283   -1.306434e+07
# 284   -6.064338e+06
# 285   -1.606434e+07
# 286   -7.564338e+06
# Name: price, Length: 287, dtype: float64

# %%
price_mean = df.price.mean()

def remean_price(row):
    row.price = row.price - price_mean
    return row

df.apply(remean_price, axis="columns").head()
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths         price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0 -1.724734e+07
# 1  2025-02-19       1085 sqft               2 BHK Flat      2 -7.064338e+06
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  3.635662e+06
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0 -1.867534e+07
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0 -1.308134e+07
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# ...

# %%
df.head(1)
# Out:
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
#
#          date           size                     type  baths      price  \
# 0  2025-02-19  799-1258 sqft  Residential land / Plot      0  2317000.0
#
#   neighborhood
# 0       Jigani

# %%
price_mean = df.price.mean()
price_mean
# Out:
# 19564337.69216028

# %%
df.city + " - " + df.type
# Out:
# 0      Bangalore - Residential land / Plot
# 1                   Bangalore - 2 BHK Flat
# 2           Bangalore - 3, 4 BHK Apartment
# 3           Bangalore - 2, 3 BHK Apartment
# 4           Bangalore - 2, 3 BHK Apartment
#                       ...
# 282           Pune - Residential apartment
# 283           Pune - Residential apartment
# 284         Pune - Independent House/Villa
# 285           Pune - Residential apartment
# 286           Pune - Residential apartment
# Length: 287, dtype: object
